# %% [markdown]
# # Problem Statement
#
# ### Credit Card Lead Prediction
#
# Happy Customer Bank is a mid-sized private bank that deals in all kinds of banking products, like Savings accounts, Current accounts, investment products, credit products, among other offerings.
#
#
# The bank also cross-sells products to its existing customers and to do so they use different kinds of communication like tele-calling, e-mails, recommendations on net banking, mobile banking, etc.
#
#
# In this case, the Happy Customer Bank wants to cross sell its credit cards to its existing customers. The bank has identified a set of customers that are eligible for taking these credit cards.
#
#
# Now, the bank is looking for your help in identifying customers that could show higher intent towards a recommended credit card, given:
#
#     Customer details (gender, age, region etc.)
#     Details of his/her relationship with the bank (Channel_Code,Vintage, 'Avg_Asset_Value etc.)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import LabelEncoder
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
from xgboost import XGBClassifier


from catboost import CatBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier

from sklearn.linear_model import LogisticRegression

pd.options.display.max_columns = 200

# %%
data = pd.read_csv("train_s3TEQDk.csv")
test = pd.read_csv("test_mSzZ8RL.csv")
print(f"Train shape {data.shape}, Test Shape {test.shape}")
# Out:
# Train shape (245725, 11), Test Shape (105312, 10)

# %%
train,valid = train_test_split(data,test_size=0.20,random_state=345,stratify=data['Is_Lead'])
train = train.copy()
valid = valid.copy()
print(f"Train shape {train.shape} Validation shape {valid.shape}")
# Out:
# Train shape (196580, 11) Validation shape (49145, 11)

# %%
train.head(3)
# Out:
#               ID  Gender  Age Region_Code     Occupation Channel_Code  \
# 53078   N3ZQ84QR  Female   46       RG280  Self_Employed           X2
# 213644  JWGAMK7P    Male   67       RG258          Other           X2
# 131870  CX9NGNQT    Male   46       RG279  Self_Employed           X2
#
#         Vintage Credit_Product  Avg_Account_Balance Is_Active  Is_Lead
# 53078        51             No               863584       Yes        0
# 213644       43            Yes               706126        No        0
# 131870       26            Yes               422207       Yes        0

# %%
test.head(3)
# Out:
#          ID Gender  Age Region_Code Occupation Channel_Code  Vintage  \
# 0  VBENBARO   Male   29       RG254      Other           X1       25
# 1  CCMEWNKY   Male   43       RG268      Other           X2       49
# 2  VK3KGA9M   Male   31       RG270   Salaried           X1       14
#
#   Credit_Product  Avg_Account_Balance Is_Active
# 0            Yes               742366        No
# 1            NaN               925537        No
# 2             No               215949        No

# %%
valid.head(3)
# Out:
#               ID  Gender  Age Region_Code     Occupation Channel_Code  \
# 148453  OK9KJGZ2  Female   55       RG268  Self_Employed           X1
# 117997  TTC7CPSI    Male   57       RG283  Self_Employed           X3
# 5432    MPUWVRAX    Male   39       RG275       Salaried           X1
#
#         Vintage Credit_Product  Avg_Account_Balance Is_Active  Is_Lead
# 148453       37             No               929257        No        0
# 117997       87            NaN               909740        No        0
# 5432          8            Yes               961742       Yes        0

# %%
train['ID'].nunique()
# Out:
# 196580

# %%
train.isna().sum()
# Out:
# ID                         0
# Gender                     0
# Age                        0
# Region_Code                0
# Occupation                 0
# Channel_Code               0
# Vintage                    0
# Credit_Product         23525
# Avg_Account_Balance        0
# Is_Active                  0
# Is_Lead                    0
# dtype: int64

# %%
train['Gender'].value_counts(normalize=True)
# Out:
# Male      0.546693
# Female    0.453307
# Name: Gender, dtype: float64

# %%
train['Region_Code'].nunique()
# Out:
# 35

# %%
train['Occupation'].value_counts(normalize=True)
# Out:
# Self_Employed    0.411532
# Salaried         0.292731
# Other            0.284866
# Entrepreneur     0.010871
# Name: Occupation, dtype: float64

# %%
train['Channel_Code'].value_counts(normalize=True)
# Out:
# X1    0.421279
# X3    0.280359
# X2    0.275669
# X4    0.022693
# Name: Channel_Code, dtype: float64

# %%
train['Credit_Product'].value_counts(normalize=True)
# Out:
# No     0.667019
# Yes    0.332981
# Name: Credit_Product, dtype: float64

# %%
train['Avg_Account_Balance'].describe()
# Out:
# count    1.965800e+05
# mean     1.129489e+06
# std      8.532486e+05
# min      2.079000e+04
# 25%      6.042470e+05
# 50%      8.954865e+05
# 75%      1.368733e+06
# max      1.035201e+07
# Name: Avg_Account_Balance, dtype: float64

# %%
train['Is_Active'].value_counts(normalize=True)
# Out:
# No     0.611375
# Yes    0.388625
# Name: Is_Active, dtype: float64

# %%
train['Is_Lead'].value_counts(normalize=True)
# Out:
# 0    0.762794
# 1    0.237206
# Name: Is_Lead, dtype: float64

# %%
train['Age'].describe()
# Out:
# count    196580.000000
# mean         43.864971
# std          14.821238
# min          23.000000
# 25%          30.000000
# 50%          43.000000
# 75%          54.000000
# max          85.000000
# Name: Age, dtype: float64

# %%
train['Vintage'].describe()
# Out:
# count    196580.000000
# mean         46.978121
# std          32.346981
# min           7.000000
# 25%          20.000000
# 50%          32.000000
# 75%          73.000000
# max         135.000000
# Name: Vintage, dtype: float64

# %%
train.groupby(['Is_Lead'])[['Age','Avg_Account_Balance']].median()
# Out:
#          Age  Avg_Account_Balance
# Is_Lead
# 0         38               871158
# 1         49               980686

# %%
train['Credit_Product'] = train['Credit_Product'].fillna('NA')
train['Avg_Account_Balance'] = np.log(1+train['Avg_Account_Balance'])

test['Credit_Product'] = test['Credit_Product'].fillna('NA')
test['Avg_Account_Balance'] = np.log(1+test['Avg_Account_Balance'])

valid['Credit_Product'] = valid['Credit_Product'].fillna('NA')
valid['Avg_Account_Balance'] = np.log(1+valid['Avg_Account_Balance'])

# %%
train.sample(3)
# Out:
#               ID  Gender  Age Region_Code     Occupation Channel_Code  \
# 144163  CAJTUNNQ    Male   32       RG260       Salaried           X1
# 242829  KDGIYR3A  Female   24       RG251       Salaried           X1
# 42203   VBJG4EXP  Female   42       RG277  Self_Employed           X2
#
#         Vintage Credit_Product  Avg_Account_Balance Is_Active  Is_Lead
# 144163       33             No            13.007130       Yes        1
# 242829       15             No            13.160129       Yes        0
# 42203        32            Yes            13.444576        No        1

# %%
train['Is_Active'] = train['Is_Active'].replace({'No':'N','Yes':'Y'})
test['Is_Active'] = test['Is_Active'].replace({'No':'N','Yes':'Y'})
valid['Is_Active'] = valid['Is_Active'].replace({'No':'N','Yes':'Y'})

# %%
cat_cols = ['Gender','Region_Code','Occupation','Channel_Code','Credit_Product','Is_Active']
featured_cols = []
for idx,col in enumerate(cat_cols):
    for sub_col in cat_cols[idx+1:]:
        new_col = f"{col}-{sub_col}"
        featured_cols.append(new_col)
        train[new_col] = train[col] + "-" + train[sub_col]
        test[new_col] = test[col] + "-" + test[sub_col]
        valid[new_col] = valid[col] + "-" + valid[sub_col]

train.sample(3)
# Out:
#               ID Gender  Age Region_Code     Occupation Channel_Code  Vintage  \
# 145908  QDDBTOEQ   Male   59       RG279          Other           X1       13
# 173895  LI6UNF8C   Male   63       RG283          Other           X3      109
# 58332   XTCVH4XR   Male   26       RG268  Self_Employed           X1       21
#
#        Credit_Product  Avg_Account_Balance Is_Active  Is_Lead  \
# 145908            Yes            13.163125         N        0
# 173895             NA            14.723440         Y        1
# 58332              No            14.051379         N        0
#
#        Gender-Region_Code   Gender-Occupation Gender-Channel_Code  \
# 145908         Male-RG279          Male-Other             Male-X1
# 173895         Male-RG283          Male-Other             Male-X3
# 58332          Male-RG268  Male-Self_Employed             Male-X1
#
#        Gender-Credit_Product Gender-Is_Active Region_Code-Occupation  \
# 145908              Male-Yes           Male-N            RG279-Other
# 173895               Male-NA           Male-Y            RG283-Other
# 58332                Male-No           Male-N    RG268-Self_Employed
#
#        Region_Code-Channel_Code Region_Code-Credit_Product  \
# 145908                 RG279-X1                  RG279-Yes
# 173895                 RG283-X3                   RG283-NA
# 58332                  RG268-X1                   RG268-No
#
#        Region_Code-Is_Active Occupation-Channel_Code  \
# 145908               RG279-N                Other-X1
# 173895               RG283-Y                Other-X3
# 58332                RG268-N        Self_Employed-X1
#
#        Occupation-Credit_Product Occupation-Is_Active  \
# 145908                 Other-Yes              Other-N
# 173895                  Other-NA              Other-Y
# 58332           Self_Employed-No      Self_Employed-N
#
#        Channel_Code-Credit_Product Channel_Code-Is_Active  \
# 145908                      X1-Yes                   X1-N
# 173895                       X3-NA                   X3-Y
# 58332                        X1-No                   X1-N
#
#        Credit_Product-Is_Active
# 145908                    Yes-N
# 173895                     NA-Y
# 58332                      No-N

# %%
all_cat_cols = cat_cols + featured_cols
num_col = ['Age','Vintage','Avg_Account_Balance']
for idx,col in enumerate (all_cat_cols):
    for ind, num in enumerate(num_col):
        print(f"Working Cat Col {col} {idx}/{len(all_cat_cols)}, Num col {num} {ind}/{len(num_col)}")
        grp = train.groupby([col])[num].agg(['mean','median','std'])
        grp = grp.add_prefix(f'{col}-{num}-')
        grp = grp.reset_index()
        train = train.merge(grp,on=[col],how='left')
        test = test.merge(grp,on=[col],how='left')
        valid = valid.merge(grp,on=[col],how='left')
# Out:
# Working Cat Col Gender 0/21, Num col Age 0/3
# Working Cat Col Gender 0/21, Num col Vintage 1/3
# Working Cat Col Gender 0/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Region_Code 1/21, Num col Age 0/3
# Working Cat Col Region_Code 1/21, Num col Vintage 1/3
# Working Cat Col Region_Code 1/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Occupation 2/21, Num col Age 0/3
# Working Cat Col Occupation 2/21, Num col Vintage 1/3
# Working Cat Col Occupation 2/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Channel_Code 3/21, Num col Age 0/3
# Working Cat Col Channel_Code 3/21, Num col Vintage 1/3
# Working Cat Col Channel_Code 3/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Credit_Product 4/21, Num col Age 0/3
# Working Cat Col Credit_Product 4/21, Num col Vintage 1/3
# Working Cat Col Credit_Product 4/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Is_Active 5/21, Num col Age 0/3
# Working Cat Col Is_Active 5/21, Num col Vintage 1/3
# Working Cat Col Is_Active 5/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Gender-Region_Code 6/21, Num col Age 0/3
# Working Cat Col Gender-Region_Code 6/21, Num col Vintage 1/3
# Working Cat Col Gender-Region_Code 6/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Gender-Occupation 7/21, Num col Age 0/3
# Working Cat Col Gender-Occupation 7/21, Num col Vintage 1/3
# Working Cat Col Gender-Occupation 7/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Gender-Channel_Code 8/21, Num col Age 0/3
# Working Cat Col Gender-Channel_Code 8/21, Num col Vintage 1/3
# Working Cat Col Gender-Channel_Code 8/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Gender-Credit_Product 9/21, Num col Age 0/3
# Working Cat Col Gender-Credit_Product 9/21, Num col Vintage 1/3
# Working Cat Col Gender-Credit_Product 9/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Gender-Is_Active 10/21, Num col Age 0/3
# Working Cat Col Gender-Is_Active 10/21, Num col Vintage 1/3
# Working Cat Col Gender-Is_Active 10/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Region_Code-Occupation 11/21, Num col Age 0/3
# Working Cat Col Region_Code-Occupation 11/21, Num col Vintage 1/3
# Working Cat Col Region_Code-Occupation 11/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Region_Code-Channel_Code 12/21, Num col Age 0/3
# Working Cat Col Region_Code-Channel_Code 12/21, Num col Vintage 1/3
# Working Cat Col Region_Code-Channel_Code 12/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Region_Code-Credit_Product 13/21, Num col Age 0/3
# Working Cat Col Region_Code-Credit_Product 13/21, Num col Vintage 1/3
# Working Cat Col Region_Code-Credit_Product 13/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Region_Code-Is_Active 14/21, Num col Age 0/3
# Working Cat Col Region_Code-Is_Active 14/21, Num col Vintage 1/3
# Working Cat Col Region_Code-Is_Active 14/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Occupation-Channel_Code 15/21, Num col Age 0/3
# Working Cat Col Occupation-Channel_Code 15/21, Num col Vintage 1/3
# Working Cat Col Occupation-Channel_Code 15/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Occupation-Credit_Product 16/21, Num col Age 0/3
# Working Cat Col Occupation-Credit_Product 16/21, Num col Vintage 1/3
# Working Cat Col Occupation-Credit_Product 16/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Occupation-Is_Active 17/21, Num col Age 0/3
# Working Cat Col Occupation-Is_Active 17/21, Num col Vintage 1/3
# Working Cat Col Occupation-Is_Active 17/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Channel_Code-Credit_Product 18/21, Num col Age 0/3
# Working Cat Col Channel_Code-Credit_Product 18/21, Num col Vintage 1/3
# Working Cat Col Channel_Code-Credit_Product 18/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Channel_Code-Is_Active 19/21, Num col Age 0/3
# Working Cat Col Channel_Code-Is_Active 19/21, Num col Vintage 1/3
# Working Cat Col Channel_Code-Is_Active 19/21, Num col Avg_Account_Balance 2/3
# Working Cat Col Credit_Product-Is_Active 20/21, Num col Age 0/3
# Working Cat Col Credit_Product-Is_Active 20/21, Num col Vintage 1/3
# Working Cat Col Credit_Product-Is_Active 20/21, Num col Avg_Account_Balance 2/3

# %%
all_cat_cols = cat_cols + featured_cols
encoder = LabelEncoder()
for col in all_cat_cols:
    train[col] = encoder.fit_transform(train[col])
    test[col] = encoder.transform(test[col])
    valid[col] = encoder.transform(valid[col])

# %%
train.sample(3)
# Out:
#               ID  Gender  Age  Region_Code  Occupation  Channel_Code  Vintage  \
# 23645   OJGYJSXW       1   61            4           3             2      122
# 169391  2ACGJZPK       1   35            4           3             1       25
# 182928  KYF2RYFH       0   31           32           2             0       31
#
#         Credit_Product  Avg_Account_Balance  Is_Active  Is_Lead  \
# 23645                1            13.337089          0        0
# 169391               1            12.803273          1        0
# 182928               1            13.846328          0        0
#
#         Gender-Region_Code  Gender-Occupation  Gender-Channel_Code  \
# 23645                   39                  7                    6
# 169391                  39                  7                    5
# 182928                  32                  2                    0
#
#         Gender-Credit_Product  Gender-Is_Active  Region_Code-Occupation  \
# 23645                       4                 2                      19
# 169391                      4                 3                      19
# 182928                      1                 0                     130
#
#         Region_Code-Channel_Code  Region_Code-Credit_Product  \
# 23645                         18                          13
# 169391                        17                          13
# 182928                       128                          97
#
#         Region_Code-Is_Active  Occupation-Channel_Code  \
# 23645                       8                       14
# 169391                      9                       13
# 182928                     64                        8
#
#         Occupation-Credit_Product  Occupation-Is_Active  \
# 23645                          10                     6
# 169391                         10                     7
# 182928                          7                     4
#
#         Channel_Code-Credit_Product  Channel_Code-Is_Active  \
# 23645                             7                       4
# 169391                            4                       3
# 182928                            1                       0
#
#         Credit_Product-Is_Active  Gender-Age-mean  Gender-Age-median  \
# 23645                          2        45.906178                 46
# 169391                         3        45.906178                 46
# 182928                         2        41.403250                 37
#
#         Gender-Age-std  Gender-Vintage-mean  Gender-Vintage-median  \
# 23645        14.621736            51.248928                     38
# 169391       14.621736            51.248928                     38
# 182928       14.685726            41.827474                     27
#
#         Gender-Vintage-std  Gender-Avg_Account_Balance-mean  \
# 23645            33.568613                        13.751552
# 169391           33.568613                        13.751552
# 182928           30.011630                        13.713333
#
#         Gender-Avg_Account_Balance-median  Gender-Avg_Account_Balance-std  \
# 23645                           13.726291                        0.617448
# 169391                          13.726291                        0.617448
# 182928                          13.680049                        0.622809
#
#         Region_Code-Age-mean  Region_Code-Age-median  Region_Code-Age-std  \
# 23645              43.716526                      43            14.818066
# 169391             43.716526                      43            14.818066
# 182928             40.763124                      35            14.349510
#
#         Region_Code-Vintage-mean  Region_Code-Vintage-median  \
# 23645                  47.403313                        32.0
# 169391                 47.403313                        32.0
# 182928                 40.640418                        31.0
#
#         Region_Code-Vintage-std  Region_Code-Avg_Account_Balance-mean  \
# 23645                 32.850418                             13.991658
# 169391                32.850418                             13.991658
# 182928                27.713310                             13.639894
#
#         Region_Code-Avg_Account_Balance-median  \
# 23645                                13.964260
# 169391                               13.964260
# 182928                               13.681643
#
#         Region_Code-Avg_Account_Balance-std  Occupation-Age-mean  \
# 23645                              0.559802            46.559537
# 169391                             0.559802            46.559537
# 182928                             0.516113            30.911582
#
#         Occupation-Age-median  Occupation-Age-std  Occupation-Vintage-mean  \
# 23645                      48            8.704273                55.551070
# 169391                     48            8.704273                55.551070
# 182928                     29            6.624586                26.385212
#
#         Occupation-Vintage-median  Occupation-Vintage-std  \
# 23645                          51               32.595353
# 169391                         51               32.595353
# 182928                         25               17.005681
#
#         Occupation-Avg_Account_Balance-mean  \
# 23645                             13.745605
# 169391                            13.745605
# 182928                            13.646255
#
#         Occupation-Avg_Account_Balance-median  \
# 23645                               13.722401
# 169391                              13.722401
# 182928                              13.609381
#
#         Occupation-Avg_Account_Balance-std  Channel_Code-Age-mean  \
# 23645                             0.607609              54.709415
# 169391                            0.607609              50.382222
# 182928                            0.617679              32.334167
#
#         Channel_Code-Age-median  Channel_Code-Age-std  \
# 23645                        53             12.125373
# 169391                       49             11.302290
# 182928                       29              9.685063
#
#         Channel_Code-Vintage-mean  Channel_Code-Vintage-median  \
# 23645                   74.830457                           80
# 169391                  54.598919                           56
# 182928                  25.316440                           25
#
#         Channel_Code-Vintage-std  Channel_Code-Avg_Account_Balance-mean  \
# 23645                  32.852358                              13.863153
# 169391                 28.159967                              13.756210
# 182928                 12.584854                              13.641346
#
#         Channel_Code-Avg_Account_Balance-median  \
# 23645                                 13.848448
# 169391                                13.735570
# 182928                                13.601937
#
#         Channel_Code-Avg_Account_Balance-std  Credit_Product-Age-mean  \
# 23645                               0.614125                40.791607
# 169391                              0.604981                40.791607
# 182928                              0.618524                40.791607
#
#         Credit_Product-Age-median  Credit_Product-Age-std  \
# 23645                          35               14.753063
# 169391                         35               14.753063
# 182928                         35               14.753063
#
#         Credit_Product-Vintage-mean  Credit_Product-Vintage-median  \
# 23645                     40.581871                             27
# 169391                    40.581871                             27
# 182928                    40.581871                             27
#
#         Credit_Product-Vintage-std  Credit_Product-Avg_Account_Balance-mean  \
# 23645                    28.885153                                13.684008
# 169391                   28.885153                                13.684008
# 182928                   28.885153                                13.684008
#
#         Credit_Product-Avg_Account_Balance-median  \
# 23645                                   13.647863
# 169391                                  13.647863
# 182928                                  13.647863
#
#         Credit_Product-Avg_Account_Balance-std  Is_Active-Age-mean  \
# 23645                                 0.624317           41.285321
# 169391                                0.624317           47.923203
# 182928                                0.624317           41.285321
#
#         Is_Active-Age-median  Is_Active-Age-std  Is_Active-Vintage-mean  \
# 23645                     36          14.618073               41.567754
# 169391                    48          14.217695               55.489554
# 182928                    36          14.618073               41.567754
#
#         Is_Active-Vintage-median  Is_Active-Vintage-std  \
# 23645                         31              29.540018
# 169391                        51              34.657305
# 182928                        31              29.540018
#
#         Is_Active-Avg_Account_Balance-mean  \
# 23645                            13.690874
# 169391                           13.802428
# 182928                           13.690874
#
#         Is_Active-Avg_Account_Balance-median  \
# 23645                              13.659566
# 169391                             13.781543
# 182928                             13.659566
#
#         Is_Active-Avg_Account_Balance-std  Gender-Region_Code-Age-mean  \
# 23645                            0.612792                    45.979602
# 169391                           0.625565                    45.979602
# 182928                           0.612792                    38.452530
#
#         Gender-Region_Code-Age-median  Gender-Region_Code-Age-std  \
# 23645                            47.0                   14.692460
# 169391                           47.0                   14.692460
# 182928                           32.0                   13.715178
#
#         Gender-Region_Code-Vintage-mean  Gender-Region_Code-Vintage-median  \
# 23645                         52.321858                               38.0
# 169391                        52.321858                               38.0
# 182928                        36.208675                               31.0
#
#         Gender-Region_Code-Vintage-std  \
# 23645                        34.365724
# 169391                       34.365724
# 182928                       24.063587
#
#         Gender-Region_Code-Avg_Account_Balance-mean  \
# 23645                                     14.000739
# 169391                                    14.000739
# 182928                                    13.629081
#
#         Gender-Region_Code-Avg_Account_Balance-median  \
# 23645                                       13.976548
# 169391                                      13.976548
# 182928                                      13.664603
#
#         Gender-Region_Code-Avg_Account_Balance-std  \
# 23645                                     0.558210
# 169391                                    0.558210
# 182928                                    0.511172
#
#         Gender-Occupation-Age-mean  Gender-Occupation-Age-median  \
# 23645                    47.293512                            48
# 169391                   47.293512                            48
# 182928                   30.233873                            29
#
#         Gender-Occupation-Age-std  Gender-Occupation-Vintage-mean  \
# 23645                    8.392542                       57.670355
# 169391                   8.392542                       57.670355
# 182928                   5.548506                       24.825372
#
#         Gender-Occupation-Vintage-median  Gender-Occupation-Vintage-std  \
# 23645                                 56                      32.912512
# 169391                                56                      32.912512
# 182928                                21                      13.665404
#
#         Gender-Occupation-Avg_Account_Balance-mean  \
# 23645                                    13.738429
# 169391                                   13.738429
# 182928                                   13.615808
#
#         Gender-Occupation-Avg_Account_Balance-median  \
# 23645                                      13.716965
# 169391                                     13.716965
# 182928                                     13.580002
#
#         Gender-Occupation-Avg_Account_Balance-std  \
# 23645                                    0.605444
# 169391                                   0.605444
# 182928                                   0.613589
#
#         Gender-Channel_Code-Age-mean  Gender-Channel_Code-Age-median  ...  \
# 23645                      55.332957                              54  ...
# 169391                     50.582740                              49  ...
# 182928                     31.947681                              29  ...
#
#         Gender-Credit_Product-Avg_Account_Balance-std  \
# 23645                                        0.625067
# 169391                                       0.625067
# 182928                                       0.622490
#
#         Gender-Is_Active-Age-mean  Gender-Is_Active-Age-median  \
# 23645                   43.444031                           42
# 169391                  49.342086                           49
# 182928                  38.938101                           32
#
#         Gender-Is_Active-Age-std  Gender-Is_Active-Vintage-mean  \
# 23645                  14.829476                      45.681388
# 169391                 13.601337                      59.018389
# 182928                 14.012360                      37.094897
#
#         Gender-Is_Active-Vintage-median  Gender-Is_Active-Vintage-std  \
# 23645                                32                     31.394054
# 169391                               57                     34.934066
# 182928                               27                     26.671735
#
#         Gender-Is_Active-Avg_Account_Balance-mean  \
# 23645                                   13.715595
# 169391                                  13.801728
# 182928                                  13.663994
#
#         Gender-Is_Active-Avg_Account_Balance-median  \
# 23645                                     13.689432
# 169391                                    13.781203
# 182928                                    13.626670
#
#         Gender-Is_Active-Avg_Account_Balance-std  \
# 23645                                   0.609421
# 169391                                  0.625037
# 182928                                  0.615316
#
#         Region_Code-Occupation-Age-mean  Region_Code-Occupation-Age-median  \
# 23645                         46.988973                               48.0
# 169391                        46.988973                               48.0
# 182928                        30.576464                               29.0
#
#         Region_Code-Occupation-Age-std  Region_Code-Occupation-Vintage-mean  \
# 23645                         8.859679                            55.804968
# 169391                        8.859679                            55.804968
# 182928                        5.573557                            26.411029
#
#         Region_Code-Occupation-Vintage-median  \
# 23645                                    51.0
# 169391                                   51.0
# 182928                                   26.0
#
#         Region_Code-Occupation-Vintage-std  \
# 23645                            33.096100
# 169391                           33.096100
# 182928                           13.140568
#
#         Region_Code-Occupation-Avg_Account_Balance-mean  \
# 23645                                         13.950268
# 169391                                        13.950268
# 182928                                        13.656512
#
#         Region_Code-Occupation-Avg_Account_Balance-median  \
# 23645                                           13.928111
# 169391                                          13.928111
# 182928                                          13.689946
#
#         Region_Code-Occupation-Avg_Account_Balance-std  \
# 23645                                         0.550486
# 169391                                        0.550486
# 182928                                        0.520300
#
#         Region_Code-Channel_Code-Age-mean  \
# 23645                           55.134468
# 169391                          51.082556
# 182928                          31.239238
#
#         Region_Code-Channel_Code-Age-median  Region_Code-Channel_Code-Age-std  \
# 23645                                  54.0                         12.039841
# 169391                                 50.0                         10.872770
# 182928                                 29.0                          7.105578
#
#         Region_Code-Channel_Code-Vintage-mean  \
# 23645                               75.378735
# 169391                              56.572030
# 182928                              25.068190
#
#         Region_Code-Channel_Code-Vintage-median  \
# 23645                                      80.0
# 169391                                     57.0
# 182928                                     26.0
#
#         Region_Code-Channel_Code-Vintage-std  \
# 23645                              33.716311
# 169391                             29.199342
# 182928                              8.768899
#
#         Region_Code-Channel_Code-Avg_Account_Balance-mean  \
# 23645                                           14.048134
# 169391                                          13.954870
# 182928                                          13.642681
#
#         Region_Code-Channel_Code-Avg_Account_Balance-median  \
# 23645                                           14.015050
# 169391                                          13.937758
# 182928                                          13.679774
#
#         Region_Code-Channel_Code-Avg_Account_Balance-std  \
# 23645                                           0.549842
# 169391                                          0.550302
# 182928                                          0.512677
#
#         Region_Code-Credit_Product-Age-mean  \
# 23645                             41.020341
# 169391                            41.020341
# 182928                            37.919215
#
#         Region_Code-Credit_Product-Age-median  \
# 23645                                    35.0
# 169391                                   35.0
# 182928                                   32.0
#
#         Region_Code-Credit_Product-Age-std  \
# 23645                            14.830789
# 169391                           14.830789
# 182928                           13.612718
#
#         Region_Code-Credit_Product-Vintage-mean  \
# 23645                                 41.716909
# 169391                                41.716909
# 182928                                35.759575
#
#         Region_Code-Credit_Product-Vintage-median  \
# 23645                                        27.0
# 169391                                       27.0
# 182928                                       31.0
#
#         Region_Code-Credit_Product-Vintage-std  \
# 23645                                29.775013
# 169391                               29.775013
# 182928                               23.748314
#
#         Region_Code-Credit_Product-Avg_Account_Balance-mean  \
# 23645                                           13.979975
# 169391                                          13.979975
# 182928                                          13.624375
#
#         Region_Code-Credit_Product-Avg_Account_Balance-median  \
# 23645                                           13.949191
# 169391                                          13.949191
# 182928                                          13.667239
#
#         Region_Code-Credit_Product-Avg_Account_Balance-std  \
# 23645                                            0.566093
# 169391                                           0.566093
# 182928                                           0.520370
#
#         Region_Code-Is_Active-Age-mean  Region_Code-Is_Active-Age-median  \
# 23645                        41.556842                              37.0
# 169391                       46.388168                              47.0
# 182928                       37.644350                              32.0
#
#         Region_Code-Is_Active-Age-std  Region_Code-Is_Active-Vintage-mean  \
# 23645                       14.632986                           43.260592
# 169391                      14.609313                           52.528075
# 182928                      13.084208                           35.392002
#
#         Region_Code-Is_Active-Vintage-median  \
# 23645                                     27
# 169391                                    38
# 182928                                    27
#
#         Region_Code-Is_Active-Vintage-std  \
# 23645                           30.415394
# 169391                          34.961976
# 182928                          24.179234
#
#         Region_Code-Is_Active-Avg_Account_Balance-mean  \
# 23645                                        13.988598
# 169391                                       13.995444
# 182928                                       13.650638
#
#         Region_Code-Is_Active-Avg_Account_Balance-median  \
# 23645                                          13.962556
# 169391                                         13.967262
# 182928                                         13.686034
#
#         Region_Code-Is_Active-Avg_Account_Balance-std  \
# 23645                                        0.556208
# 169391                                       0.564224
# 182928                                       0.511757
#
#         Occupation-Channel_Code-Age-mean  Occupation-Channel_Code-Age-median  \
# 23645                          50.100950                                  51
# 169391                         47.153494                                  47
# 182928                         29.342995                                  29
#
#         Occupation-Channel_Code-Age-std  Occupation-Channel_Code-Vintage-mean  \
# 23645                          6.705361                             73.301676
# 169391                         7.104712                             53.313132
# 182928                         3.403885                             22.884158
#
#         Occupation-Channel_Code-Vintage-median  \
# 23645                                     79.0
# 169391                                    55.0
# 182928                                    21.0
#
#         Occupation-Channel_Code-Vintage-std  \
# 23645                             32.354135
# 169391                            27.966771
# 182928                             7.426934
#
#         Occupation-Channel_Code-Avg_Account_Balance-mean  \
# 23645                                          13.825329
# 169391                                         13.726652
# 182928                                         13.621987
#
#         Occupation-Channel_Code-Avg_Account_Balance-median  \
# 23645                                           13.810187
# 169391                                          13.706341
# 182928                                          13.584699
#
#         Occupation-Channel_Code-Avg_Account_Balance-std  \
# 23645                                          0.605881
# 169391                                         0.598040
# 182928                                         0.611982
#
#         Occupation-Credit_Product-Age-mean  \
# 23645                            45.354059
# 169391                           45.354059
# 182928                           29.560430
#
#         Occupation-Credit_Product-Age-median  \
# 23645                                     47
# 169391                                    47
# 182928                                    29
#
#         Occupation-Credit_Product-Age-std  \
# 23645                            9.352548
# 169391                           9.352548
# 182928                           3.889061
#
#         Occupation-Credit_Product-Vintage-mean  \
# 23645                                51.904785
# 169391                               51.904785
# 182928                               23.426746
#
#         Occupation-Credit_Product-Vintage-median  \
# 23645                                         49
# 169391                                        49
# 182928                                        21
#
#         Occupation-Credit_Product-Vintage-std  \
# 23645                               31.022695
# 169391                              31.022695
# 182928                               9.253663
#
#         Occupation-Credit_Product-Avg_Account_Balance-mean  \
# 23645                                           13.705602
# 169391                                          13.705602
# 182928                                          13.619111
#
#         Occupation-Credit_Product-Avg_Account_Balance-median  \
# 23645                                           13.672885
# 169391                                          13.672885
# 182928                                          13.579394
#
#         Occupation-Credit_Product-Avg_Account_Balance-std  \
# 23645                                            0.616762
# 169391                                           0.616762
# 182928                                           0.617434
#
#         Occupation-Is_Active-Age-mean  Occupation-Is_Active-Age-median  \
# 23645                       45.697397                               47
# 169391                      47.476003                               48
# 182928                      30.476931                               29
#
#         Occupation-Is_Active-Age-std  Occupation-Is_Active-Vintage-mean  \
# 23645                       9.279214                          52.037951
# 169391                      7.946399                          59.285561
# 182928                      5.708913                          25.479779
#
#         Occupation-Is_Active-Vintage-median  Occupation-Is_Active-Vintage-std  \
# 23645                                    49                         31.448600
# 169391                                   57                         33.368966
# 182928                                   25                         14.052418
#
#         Occupation-Is_Active-Avg_Account_Balance-mean  \
# 23645                                       13.723480
# 169391                                      13.769124
# 182928                                      13.602420
#
#         Occupation-Is_Active-Avg_Account_Balance-median  \
# 23645                                         13.698787
# 169391                                        13.749167
# 182928                                        13.567376
#
#         Occupation-Is_Active-Avg_Account_Balance-std  \
# 23645                                       0.597698
# 169391                                      0.617108
# 182928                                      0.607033
#
#         Channel_Code-Credit_Product-Age-mean  \
# 23645                              55.160681
# 169391                             50.699305
# 182928                             31.437029
#
#         Channel_Code-Credit_Product-Age-median  \
# 23645                                       54
# 169391                                      49
# 182928                                      29
#
#         Channel_Code-Credit_Product-Age-std  \
# 23645                             12.968310
# 169391                            11.595563
# 182928                             8.277654
#
#         Channel_Code-Credit_Product-Vintage-mean  \
# 23645                                  72.752381
# 169391                                 53.602277
# 182928                                 24.406913
#
#         Channel_Code-Credit_Product-Vintage-median  \
# 23645                                           74
# 169391                                          55
# 182928                                          25
#
#         Channel_Code-Credit_Product-Vintage-std  \
# 23645                                 32.049188
# 169391                                26.623489
# 182928                                10.435279
#
#         Channel_Code-Credit_Product-Avg_Account_Balance-mean  \
# 23645                                           13.810513
# 169391                                          13.728676
# 182928                                          13.622954
#
#         Channel_Code-Credit_Product-Avg_Account_Balance-median  \
# 23645                                           13.787153
# 169391                                          13.700990
# 182928                                          13.581629
#
#         Channel_Code-Credit_Product-Avg_Account_Balance-std  \
# 23645                                            0.624411
# 169391                                           0.618954
# 182928                                           0.618630
#
#         Channel_Code-Is_Active-Age-mean  Channel_Code-Is_Active-Age-median  \
# 23645                         54.145345                                 53
# 169391                        50.028448                                 48
# 182928                        31.905289                                 29
#
#         Channel_Code-Is_Active-Age-std  Channel_Code-Is_Active-Vintage-mean  \
# 23645                        12.732743                            70.575908
# 169391                       11.195013                            53.959872
# 182928                        8.829930                            24.890678
#
#         Channel_Code-Is_Active-Vintage-median  \
# 23645                                      74
# 169391                                     55
# 182928                                     25
#
#         Channel_Code-Is_Active-Vintage-std  \
# 23645                            33.149403
# 169391                           28.684730
# 182928                           10.778658
#
#         Channel_Code-Is_Active-Avg_Account_Balance-mean  \
# 23645                                         13.845411
# 169391                                        13.748476
# 182928                                        13.599267
#
#         Channel_Code-Is_Active-Avg_Account_Balance-median  \
# 23645                                           13.829655
# 169391                                          13.727760
# 182928                                          13.562733
#
#         Channel_Code-Is_Active-Avg_Account_Balance-std  \
# 23645                                         0.606719
# 169391                                        0.617820
# 182928                                        0.608134
#
#         Credit_Product-Is_Active-Age-mean  \
# 23645                           37.114239
# 169391                          46.009136
# 182928                          37.114239
#
#         Credit_Product-Is_Active-Age-median  Credit_Product-Is_Active-Age-std  \
# 23645                                    31                         13.289813
# 169391                                   46                         15.148168
# 182928                                   31                         13.289813
#
#         Credit_Product-Is_Active-Vintage-mean  \
# 23645                               35.176062
# 169391                              48.251750
# 182928                              35.176062
#
#         Credit_Product-Is_Active-Vintage-median  \
# 23645                                        27
# 169391                                       33
# 182928                                       27
#
#         Credit_Product-Is_Active-Vintage-std  \
# 23645                              24.514767
# 169391                             32.637442
# 182928                             24.514767
#
#         Credit_Product-Is_Active-Avg_Account_Balance-mean  \
# 23645                                           13.627760
# 169391                                          13.763813
# 182928                                          13.627760
#
#         Credit_Product-Is_Active-Avg_Account_Balance-median  \
# 23645                                           13.589475
# 169391                                          13.738150
# 182928                                          13.589475
#
#         Credit_Product-Is_Active-Avg_Account_Balance-std
# 23645                                           0.613927
# 169391                                          0.630220
# 182928                                          0.613927
#
# [3 rows x 215 columns]

# %%
test.sample(3)
# Out:
#              ID  Gender  Age  Region_Code  Occupation  Channel_Code  Vintage  \
# 66727  95NZKCKG       1   42           33           3             0       74
# 26276  DZXXQYTF       1   30           18           1             0       27
# 96829  STQYKPZN       1   49           10           3             1       93
#
#        Credit_Product  Avg_Account_Balance  Is_Active  Gender-Region_Code  \
# 66727               2            14.321911          0                  68
# 26276               1            13.650155          0                  53
# 96829               1            13.959247          0                  45
#
#        Gender-Occupation  Gender-Channel_Code  Gender-Credit_Product  \
# 66727                  7                    4                      5
# 26276                  5                    4                      4
# 96829                  7                    5                      4
#
#        Gender-Is_Active  Region_Code-Occupation  Region_Code-Channel_Code  \
# 66727                 2                     135                       132
# 26276                 2                      73                        72
# 96829                 2                      43                        41
#
#        Region_Code-Credit_Product  Region_Code-Is_Active  \
# 66727                         101                     66
# 26276                          55                     36
# 96829                          31                     20
#
#        Occupation-Channel_Code  Occupation-Credit_Product  \
# 66727                       12                         11
# 26276                        4                          4
# 96829                       13                         10
#
#        Occupation-Is_Active  Channel_Code-Credit_Product  \
# 66727                     6                            2
# 26276                     2                            1
# 96829                     6                            4
#
#        Channel_Code-Is_Active  Credit_Product-Is_Active  Gender-Age-mean  \
# 66727                       0                         4        45.906178
# 26276                       0                         2        45.906178
# 96829                       2                         2        45.906178
#
#        Gender-Age-median  Gender-Age-std  Gender-Vintage-mean  \
# 66727                 46       14.621736            51.248928
# 26276                 46       14.621736            51.248928
# 96829                 46       14.621736            51.248928
#
#        Gender-Vintage-median  Gender-Vintage-std  \
# 66727                     38           33.568613
# 26276                     38           33.568613
# 96829                     38           33.568613
#
#        Gender-Avg_Account_Balance-mean  Gender-Avg_Account_Balance-median  \
# 66727                        13.751552                          13.726291
# 26276                        13.751552                          13.726291
# 96829                        13.751552                          13.726291
#
#        Gender-Avg_Account_Balance-std  Region_Code-Age-mean  \
# 66727                        0.617448             49.038860
# 26276                        0.617448             49.016579
# 96829                        0.617448             40.393964
#
#        Region_Code-Age-median  Region_Code-Age-std  Region_Code-Vintage-mean  \
# 66727                      49            14.141979                 58.949928
# 26276                      49            14.133032                 59.242276
# 96829                      34            14.243897                 40.410865
#
#        Region_Code-Vintage-median  Region_Code-Vintage-std  \
# 66727                        57.0                33.935316
# 26276                        57.0                34.127409
# 96829                        31.0                28.117289
#
#        Region_Code-Avg_Account_Balance-mean  \
# 66727                             14.020919
# 26276                             14.013321
# 96829                             13.374431
#
#        Region_Code-Avg_Account_Balance-median  \
# 66727                               14.015742
# 26276                               14.011128
# 96829                               13.340758
#
#        Region_Code-Avg_Account_Balance-std  Occupation-Age-mean  \
# 66727                             0.595516            46.559537
# 26276                             0.594250            53.130842
# 96829                             0.574998            46.559537
#
#        Occupation-Age-median  Occupation-Age-std  Occupation-Vintage-mean  \
# 66727                     48            8.704273                55.551070
# 26276                     56           18.615624                54.886123
# 96829                     48            8.704273                55.551070
#
#        Occupation-Vintage-median  Occupation-Vintage-std  \
# 66727                         51               32.595353
# 26276                         50               34.306833
# 96829                         51               32.595353
#
#        Occupation-Avg_Account_Balance-mean  \
# 66727                            13.745605
# 26276                            13.798887
# 96829                            13.745605
#
#        Occupation-Avg_Account_Balance-median  \
# 66727                              13.722401
# 26276                              13.774818
# 96829                              13.722401
#
#        Occupation-Avg_Account_Balance-std  Channel_Code-Age-mean  \
# 66727                            0.607609              32.334167
# 26276                            0.630414              32.334167
# 96829                            0.607609              50.382222
#
#        Channel_Code-Age-median  Channel_Code-Age-std  \
# 66727                       29              9.685063
# 26276                       29              9.685063
# 96829                       49             11.302290
#
#        Channel_Code-Vintage-mean  Channel_Code-Vintage-median  \
# 66727                  25.316440                           25
# 26276                  25.316440                           25
# 96829                  54.598919                           56
#
#        Channel_Code-Vintage-std  Channel_Code-Avg_Account_Balance-mean  \
# 66727                 12.584854                              13.641346
# 26276                 12.584854                              13.641346
# 96829                 28.159967                              13.756210
#
#        Channel_Code-Avg_Account_Balance-median  \
# 66727                                13.601937
# 26276                                13.601937
# 96829                                13.735570
#
#        Channel_Code-Avg_Account_Balance-std  Credit_Product-Age-mean  \
# 66727                              0.618524                46.864084
# 26276                              0.618524                40.791607
# 96829                              0.604981                40.791607
#
#        Credit_Product-Age-median  Credit_Product-Age-std  \
# 66727                         47               14.195920
# 26276                         35               14.753063
# 96829                         35               14.753063
#
#        Credit_Product-Vintage-mean  Credit_Product-Vintage-median  \
# 66727                    51.701079                             39
# 26276                    40.581871                             27
# 96829                    40.581871                             27
#
#        Credit_Product-Vintage-std  Credit_Product-Avg_Account_Balance-mean  \
# 66727                   34.259627                                13.794534
# 26276                   28.885153                                13.684008
# 96829                   28.885153                                13.684008
#
#        Credit_Product-Avg_Account_Balance-median  \
# 66727                                  13.771814
# 26276                                  13.647863
# 96829                                  13.647863
#
#        Credit_Product-Avg_Account_Balance-std  Is_Active-Age-mean  \
# 66727                                0.608655           41.285321
# 26276                                0.624317           41.285321
# 96829                                0.624317           41.285321
#
#        Is_Active-Age-median  Is_Active-Age-std  Is_Active-Vintage-mean  \
# 66727                    36          14.618073               41.567754
# 26276                    36          14.618073               41.567754
# 96829                    36          14.618073               41.567754
#
#        Is_Active-Vintage-median  Is_Active-Vintage-std  \
# 66727                        31              29.540018
# 26276                        31              29.540018
# 96829                        31              29.540018
#
#        Is_Active-Avg_Account_Balance-mean  \
# 66727                           13.690874
# 26276                           13.690874
# 96829                           13.690874
#
#        Is_Active-Avg_Account_Balance-median  \
# 66727                             13.659566
# 26276                             13.659566
# 96829                             13.659566
#
#        Is_Active-Avg_Account_Balance-std  Gender-Region_Code-Age-mean  \
# 66727                           0.612792                    50.099778
# 26276                           0.612792                    50.065278
# 96829                           0.612792                    43.508124
#
#        Gender-Region_Code-Age-median  Gender-Region_Code-Age-std  \
# 66727                           49.0                   13.653215
# 26276                           50.0                   13.606399
# 96829                           42.0                   14.552360
#
#        Gender-Region_Code-Vintage-mean  Gender-Region_Code-Vintage-median  \
# 66727                        61.784858                               62.0
# 26276                        62.161170                               62.0
# 96829                        46.258493                               32.0
#
#        Gender-Region_Code-Vintage-std  \
# 66727                       33.889134
# 26276                       34.078826
# 96829                       30.996573
#
#        Gender-Region_Code-Avg_Account_Balance-mean  \
# 66727                                    14.025825
# 26276                                    14.016509
# 96829                                    13.408011
#
#        Gender-Region_Code-Avg_Account_Balance-median  \
# 66727                                      14.017518
# 26276                                      14.005866
# 96829                                      13.381694
#
#        Gender-Region_Code-Avg_Account_Balance-std  Gender-Occupation-Age-mean  \
# 66727                                    0.592916                   47.293512
# 26276                                    0.593029                   55.304334
# 96829                                    0.580539                   47.293512
#
#        Gender-Occupation-Age-median  Gender-Occupation-Age-std  \
# 66727                            48                   8.392542
# 26276                            60                  17.651923
# 96829                            48                   8.392542
#
#        Gender-Occupation-Vintage-mean  Gender-Occupation-Vintage-median  \
# 66727                       57.670355                                56
# 26276                       59.464858                                57
# 96829                       57.670355                                56
#
#        Gender-Occupation-Vintage-std  \
# 66727                      32.912512
# 26276                      34.764459
# 96829                      32.912512
#
#        Gender-Occupation-Avg_Account_Balance-mean  \
# 66727                                   13.738429
# 26276                                   13.818952
# 96829                                   13.738429
#
#        Gender-Occupation-Avg_Account_Balance-median  \
# 66727                                     13.716965
# 26276                                     13.796086
# 96829                                     13.716965
#
#        Gender-Occupation-Avg_Account_Balance-std  \
# 66727                                   0.605444
# 26276                                   0.625990
# 96829                                   0.605444
#
#        Gender-Channel_Code-Age-mean  Gender-Channel_Code-Age-median  \
# 66727                     32.826819                              29
# 26276                     32.826819                              29
# 96829                     50.582740                              49
#
#        Gender-Channel_Code-Age-std  ...  \
# 66727                    10.206629  ...
# 26276                    10.206629  ...
# 96829                    10.999853  ...
#
#        Gender-Credit_Product-Avg_Account_Balance-std  \
# 66727                                       0.604623
# 26276                                       0.625067
# 96829                                       0.625067
#
#        Gender-Is_Active-Age-mean  Gender-Is_Active-Age-median  \
# 66727                  43.444031                           42
# 26276                  43.444031                           42
# 96829                  43.444031                           42
#
#        Gender-Is_Active-Age-std  Gender-Is_Active-Vintage-mean  \
# 66727                 14.829476                      45.681388
# 26276                 14.829476                      45.681388
# 96829                 14.829476                      45.681388
#
#        Gender-Is_Active-Vintage-median  Gender-Is_Active-Vintage-std  \
# 66727                               32                     31.394054
# 26276                               32                     31.394054
# 96829                               32                     31.394054
#
#        Gender-Is_Active-Avg_Account_Balance-mean  \
# 66727                                  13.715595
# 26276                                  13.715595
# 96829                                  13.715595
#
#        Gender-Is_Active-Avg_Account_Balance-median  \
# 66727                                    13.689432
# 26276                                    13.689432
# 96829                                    13.689432
#
#        Gender-Is_Active-Avg_Account_Balance-std  \
# 66727                                  0.609421
# 26276                                  0.609421
# 96829                                  0.609421
#
#        Region_Code-Occupation-Age-mean  Region_Code-Occupation-Age-median  \
# 66727                        47.888273                               48.0
# 26276                        59.175442                               63.0
# 96829                        45.306193                               46.0
#
#        Region_Code-Occupation-Age-std  Region_Code-Occupation-Vintage-mean  \
# 66727                        7.582412                            63.168501
# 26276                       16.224971                            66.165597
# 96829                        9.444578                            50.402523
#
#        Region_Code-Occupation-Vintage-median  \
# 66727                                   63.0
# 26276                                   68.0
# 96829                                   43.0
#
#        Region_Code-Occupation-Vintage-std  \
# 66727                           32.304118
# 26276                           34.110853
# 96829                           31.863041
#
#        Region_Code-Occupation-Avg_Account_Balance-mean  \
# 66727                                        13.978860
# 26276                                        14.056102
# 96829                                        13.395641
#
#        Region_Code-Occupation-Avg_Account_Balance-median  \
# 66727                                          13.967018
# 26276                                          14.066017
# 96829                                          13.365528
#
#        Region_Code-Occupation-Avg_Account_Balance-std  \
# 66727                                        0.587847
# 26276                                        0.604029
# 96829                                        0.577238
#
#        Region_Code-Channel_Code-Age-mean  Region_Code-Channel_Code-Age-median  \
# 66727                          38.341542                                 31.0
# 26276                          38.307069                                 31.0
# 96829                          50.862306                                 49.0
#
#        Region_Code-Channel_Code-Age-std  \
# 66727                         14.820396
# 26276                         14.781783
# 96829                         11.915434
#
#        Region_Code-Channel_Code-Vintage-mean  \
# 66727                              32.155379
# 26276                              31.828172
# 96829                              52.120482
#
#        Region_Code-Channel_Code-Vintage-median  \
# 66727                                     26.0
# 26276                                     26.0
# 96829                                     50.0
#
#        Region_Code-Channel_Code-Vintage-std  \
# 66727                             20.710089
# 26276                             20.662957
# 96829                             29.442099
#
#        Region_Code-Channel_Code-Avg_Account_Balance-mean  \
# 66727                                          14.021016
# 26276                                          14.019672
# 96829                                          13.416928
#
#        Region_Code-Channel_Code-Avg_Account_Balance-median  \
# 66727                                          14.017787
# 26276                                          14.015414
# 96829                                          13.382169
#
#        Region_Code-Channel_Code-Avg_Account_Balance-std  \
# 66727                                          0.618966
# 26276                                          0.619927
# 96829                                          0.606143
#
#        Region_Code-Credit_Product-Age-mean  \
# 66727                            51.052599
# 26276                            46.157220
# 96829                            37.356024
#
#        Region_Code-Credit_Product-Age-median  \
# 66727                                   50.0
# 26276                                   46.0
# 96829                                   31.0
#
#        Region_Code-Credit_Product-Age-std  \
# 66727                           12.973797
# 26276                           15.029966
# 96829                           13.414219
#
#        Region_Code-Credit_Product-Vintage-mean  \
# 66727                                62.473023
# 26276                                52.012814
# 96829                                35.566867
#
#        Region_Code-Credit_Product-Vintage-median  \
# 66727                                       62.0
# 26276                                       44.0
# 96829                                       27.0
#
#        Region_Code-Credit_Product-Vintage-std  \
# 66727                               34.593373
# 26276                               32.819819
# 96829                               23.868456
#
#        Region_Code-Credit_Product-Avg_Account_Balance-mean  \
# 66727                                          14.050301
# 26276                                          13.990097
# 96829                                          13.341600
#
#        Region_Code-Credit_Product-Avg_Account_Balance-median  \
# 66727                                          14.048077
# 26276                                          13.979808
# 96829                                          13.297305
#
#        Region_Code-Credit_Product-Avg_Account_Balance-std  \
# 66727                                           0.578569
# 26276                                           0.608925
# 96829                                           0.571299
#
#        Region_Code-Is_Active-Age-mean  Region_Code-Is_Active-Age-median  \
# 66727                       49.041642                              49.0
# 26276                       49.065480                              49.0
# 96829                       37.254415                              31.0
#
#        Region_Code-Is_Active-Age-std  Region_Code-Is_Active-Vintage-mean  \
# 66727                      14.323854                           57.077298
# 26276                      14.370139                           57.380598
# 96829                      12.817233                           36.081126
#
#        Region_Code-Is_Active-Vintage-median  \
# 66727                                    55
# 26276                                    55
# 96829                                    27
#
#        Region_Code-Is_Active-Vintage-std  \
# 66727                          32.513307
# 26276                          32.795914
# 96829                          24.232892
#
#        Region_Code-Is_Active-Avg_Account_Balance-mean  \
# 66727                                       14.021352
# 26276                                       14.017349
# 96829                                       13.364664
#
#        Region_Code-Is_Active-Avg_Account_Balance-median  \
# 66727                                         14.013357
# 26276                                         14.016863
# 96829                                         13.330468
#
#        Region_Code-Is_Active-Avg_Account_Balance-std  \
# 66727                                       0.588656
# 26276                                       0.588426
# 96829                                       0.568735
#
#        Occupation-Channel_Code-Age-mean  Occupation-Channel_Code-Age-median  \
# 66727                         37.666341                                  35
# 26276                         36.419296                                  30
# 96829                         47.153494                                  47
#
#        Occupation-Channel_Code-Age-std  Occupation-Channel_Code-Vintage-mean  \
# 66727                        10.237646                             30.848173
# 26276                        15.566254                             27.707784
# 96829                         7.104712                             53.313132
#
#        Occupation-Channel_Code-Vintage-median  \
# 66727                                    26.0
# 26276                                    25.0
# 96829                                    55.0
#
#        Occupation-Channel_Code-Vintage-std  \
# 66727                            18.336994
# 26276                            16.014826
# 96829                            27.966771
#
#        Occupation-Channel_Code-Avg_Account_Balance-mean  \
# 66727                                         13.656689
# 26276                                         13.678502
# 96829                                         13.726652
#
#        Occupation-Channel_Code-Avg_Account_Balance-median  \
# 66727                                          13.612417
# 26276                                          13.636975
# 96829                                          13.706341
#
#        Occupation-Channel_Code-Avg_Account_Balance-std  \
# 66727                                         0.617393
# 26276                                         0.633103
# 96829                                         0.598040
#
#        Occupation-Credit_Product-Age-mean  \
# 66727                           47.475027
# 26276                           49.624410
# 96829                           45.354059
#
#        Occupation-Credit_Product-Age-median  \
# 66727                                    48
# 26276                                    48
# 96829                                    47
#
#        Occupation-Credit_Product-Age-std  \
# 66727                           8.047989
# 26276                          19.664724
# 96829                           9.352548
#
#        Occupation-Credit_Product-Vintage-mean  \
# 66727                               56.462920
# 26276                               48.276304
# 96829                               51.904785
#
#        Occupation-Credit_Product-Vintage-median  \
# 66727                                        55
# 26276                                        33
# 96829                                        49
#
#        Occupation-Credit_Product-Vintage-std  \
# 66727                              33.669439
# 26276                              32.204767
# 96829                              31.022695
#
#        Occupation-Credit_Product-Avg_Account_Balance-mean  \
# 66727                                          13.784911
# 26276                                          13.741391
# 96829                                          13.705602
#
#        Occupation-Credit_Product-Avg_Account_Balance-median  \
# 66727                                          13.767253
# 26276                                          13.710649
# 96829                                          13.672885
#
#        Occupation-Credit_Product-Avg_Account_Balance-std  \
# 66727                                           0.595917
# 26276                                           0.635718
# 96829                                           0.616762
#
#        Occupation-Is_Active-Age-mean  Occupation-Is_Active-Age-median  \
# 66727                      45.697397                               47
# 26276                      49.951290                               50
# 96829                      45.697397                               47
#
#        Occupation-Is_Active-Age-std  Occupation-Is_Active-Vintage-mean  \
# 66727                      9.279214                          52.037951
# 26276                     19.146527                          49.045805
# 96829                      9.279214                          52.037951
#
#        Occupation-Is_Active-Vintage-median  Occupation-Is_Active-Vintage-std  \
# 66727                                   49                         31.448600
# 26276                                   33                         32.594454
# 96829                                   49                         31.448600
#
#        Occupation-Is_Active-Avg_Account_Balance-mean  \
# 66727                                       13.72348
# 26276                                       13.75803
# 96829                                       13.72348
#
#        Occupation-Is_Active-Avg_Account_Balance-median  \
# 66727                                        13.698787
# 26276                                        13.730922
# 96829                                        13.698787
#
#        Occupation-Is_Active-Avg_Account_Balance-std  \
# 66727                                      0.597698
# 26276                                      0.625097
# 96829                                      0.597698
#
#        Channel_Code-Credit_Product-Age-mean  \
# 66727                             34.347592
# 26276                             31.437029
# 96829                             50.699305
#
#        Channel_Code-Credit_Product-Age-median  \
# 66727                                      29
# 26276                                      29
# 96829                                      49
#
#        Channel_Code-Credit_Product-Age-std  \
# 66727                            12.273945
# 26276                             8.277654
# 96829                            11.595563
#
#        Channel_Code-Credit_Product-Vintage-mean  \
# 66727                                 26.619366
# 26276                                 24.406913
# 96829                                 53.602277
#
#        Channel_Code-Credit_Product-Vintage-median  \
# 66727                                          25
# 26276                                          25
# 96829                                          55
#
#        Channel_Code-Credit_Product-Vintage-std  \
# 66727                                15.423915
# 26276                                10.435279
# 96829                                26.623489
#
#        Channel_Code-Credit_Product-Avg_Account_Balance-mean  \
# 66727                                          13.690755
# 26276                                          13.622954
# 96829                                          13.728676
#
#        Channel_Code-Credit_Product-Avg_Account_Balance-median  \
# 66727                                          13.663485
# 26276                                          13.581629
# 96829                                          13.700990
#
#        Channel_Code-Credit_Product-Avg_Account_Balance-std  \
# 66727                                           0.610405
# 26276                                           0.618630
# 96829                                           0.618954
#
#        Channel_Code-Is_Active-Age-mean  Channel_Code-Is_Active-Age-median  \
# 66727                        31.905289                                 29
# 26276                        31.905289                                 29
# 96829                        50.757953                                 49
#
#        Channel_Code-Is_Active-Age-std  Channel_Code-Is_Active-Vintage-mean  \
# 66727                        8.829930                            24.890678
# 26276                        8.829930                            24.890678
# 96829                       11.403322                            55.277626
#
#        Channel_Code-Is_Active-Vintage-median  \
# 66727                                     25
# 26276                                     25
# 96829                                     57
#
#        Channel_Code-Is_Active-Vintage-std  \
# 66727                           10.778658
# 26276                           10.778658
# 96829                           27.576043
#
#        Channel_Code-Is_Active-Avg_Account_Balance-mean  \
# 66727                                        13.599267
# 26276                                        13.599267
# 96829                                        13.764424
#
#        Channel_Code-Is_Active-Avg_Account_Balance-median  \
# 66727                                          13.562733
# 26276                                          13.562733
# 96829                                          13.742765
#
#        Channel_Code-Is_Active-Avg_Account_Balance-std  \
# 66727                                        0.608134
# 26276                                        0.608134
# 96829                                        0.590941
#
#        Credit_Product-Is_Active-Age-mean  Credit_Product-Is_Active-Age-median  \
# 66727                          45.197443                                   45
# 26276                          37.114239                                   31
# 96829                          37.114239                                   31
#
#        Credit_Product-Is_Active-Age-std  \
# 66727                         14.694064
# 26276                         13.289813
# 96829                         13.289813
#
#        Credit_Product-Is_Active-Vintage-mean  \
# 66727                              45.636257
# 26276                              35.176062
# 96829                              35.176062
#
#        Credit_Product-Is_Active-Vintage-median  \
# 66727                                       32
# 26276                                       27
# 96829                                       27
#
#        Credit_Product-Is_Active-Vintage-std  \
# 66727                             32.006965
# 26276                             24.514767
# 96829                             24.514767
#
#        Credit_Product-Is_Active-Avg_Account_Balance-mean  \
# 66727                                          13.761389
# 26276                                          13.627760
# 96829                                          13.627760
#
#        Credit_Product-Is_Active-Avg_Account_Balance-median  \
# 66727                                          13.736186
# 26276                                          13.589475
# 96829                                          13.589475
#
#        Credit_Product-Is_Active-Avg_Account_Balance-std
# 66727                                          0.602281
# 26276                                          0.613927
# 96829                                          0.613927
#
# [3 rows x 214 columns]

# %%
valid.sample(3)
# Out:
#              ID  Gender  Age  Region_Code  Occupation  Channel_Code  Vintage  \
# 6587   58WEG7YP       0   34            7           2             0       27
# 9825   9JUBRDIM       1   63           33           1             1       39
# 29143  GC3KESLX       1   57            4           3             2       63
#
#        Credit_Product  Avg_Account_Balance  Is_Active  Is_Lead  \
# 6587                1            13.532107          0        0
# 9825                1            13.835857          1        0
# 29143               1            14.744259          0        0
#
#        Gender-Region_Code  Gender-Occupation  Gender-Channel_Code  \
# 6587                    7                  2                    0
# 9825                   68                  5                    5
# 29143                  39                  7                    6
#
#        Gender-Credit_Product  Gender-Is_Active  Region_Code-Occupation  \
# 6587                       1                 0                      30
# 9825                       4                 3                     133
# 29143                      4                 2                      19
#
#        Region_Code-Channel_Code  Region_Code-Credit_Product  \
# 6587                         28                          22
# 9825                        133                         100
# 29143                        18                          13
#
#        Region_Code-Is_Active  Occupation-Channel_Code  \
# 6587                      14                        8
# 9825                      67                        5
# 29143                      8                       14
#
#        Occupation-Credit_Product  Occupation-Is_Active  \
# 6587                           7                     4
# 9825                           4                     3
# 29143                         10                     6
#
#        Channel_Code-Credit_Product  Channel_Code-Is_Active  \
# 6587                             1                       0
# 9825                             4                       3
# 29143                            7                       4
#
#        Credit_Product-Is_Active  Gender-Age-mean  Gender-Age-median  \
# 6587                          2        41.403250                 37
# 9825                          3        45.906178                 46
# 29143                         2        45.906178                 46
#
#        Gender-Age-std  Gender-Vintage-mean  Gender-Vintage-median  \
# 6587        14.685726            41.827474                     27
# 9825        14.621736            51.248928                     38
# 29143       14.621736            51.248928                     38
#
#        Gender-Vintage-std  Gender-Avg_Account_Balance-mean  \
# 6587            30.011630                        13.713333
# 9825            33.568613                        13.751552
# 29143           33.568613                        13.751552
#
#        Gender-Avg_Account_Balance-median  Gender-Avg_Account_Balance-std  \
# 6587                           13.680049                        0.622809
# 9825                           13.726291                        0.617448
# 29143                          13.726291                        0.617448
#
#        Region_Code-Age-mean  Region_Code-Age-median  Region_Code-Age-std  \
# 6587              39.151274                      32            13.959944
# 9825              49.038860                      49            14.141979
# 29143             43.716526                      43            14.818066
#
#        Region_Code-Vintage-mean  Region_Code-Vintage-median  \
# 6587                  37.854842                        27.0
# 9825                  58.949928                        57.0
# 29143                 47.403313                        32.0
#
#        Region_Code-Vintage-std  Region_Code-Avg_Account_Balance-mean  \
# 6587                 27.606765                             13.493599
# 9825                 33.935316                             14.020919
# 29143                32.850418                             13.991658
#
#        Region_Code-Avg_Account_Balance-median  \
# 6587                                13.465645
# 9825                                14.015742
# 29143                               13.964260
#
#        Region_Code-Avg_Account_Balance-std  Occupation-Age-mean  \
# 6587                              0.571355            30.911582
# 9825                              0.595516            53.130842
# 29143                             0.559802            46.559537
#
#        Occupation-Age-median  Occupation-Age-std  Occupation-Vintage-mean  \
# 6587                      29            6.624586                26.385212
# 9825                      56           18.615624                54.886123
# 29143                     48            8.704273                55.551070
#
#        Occupation-Vintage-median  Occupation-Vintage-std  \
# 6587                          25               17.005681
# 9825                          50               34.306833
# 29143                         51               32.595353
#
#        Occupation-Avg_Account_Balance-mean  \
# 6587                             13.646255
# 9825                             13.798887
# 29143                            13.745605
#
#        Occupation-Avg_Account_Balance-median  \
# 6587                               13.609381
# 9825                               13.774818
# 29143                              13.722401
#
#        Occupation-Avg_Account_Balance-std  Channel_Code-Age-mean  \
# 6587                             0.617679              32.334167
# 9825                             0.630414              50.382222
# 29143                            0.607609              54.709415
#
#        Channel_Code-Age-median  Channel_Code-Age-std  \
# 6587                        29              9.685063
# 9825                        49             11.302290
# 29143                       53             12.125373
#
#        Channel_Code-Vintage-mean  Channel_Code-Vintage-median  \
# 6587                   25.316440                           25
# 9825                   54.598919                           56
# 29143                  74.830457                           80
#
#        Channel_Code-Vintage-std  Channel_Code-Avg_Account_Balance-mean  \
# 6587                  12.584854                              13.641346
# 9825                  28.159967                              13.756210
# 29143                 32.852358                              13.863153
#
#        Channel_Code-Avg_Account_Balance-median  \
# 6587                                 13.601937
# 9825                                 13.735570
# 29143                                13.848448
#
#        Channel_Code-Avg_Account_Balance-std  Credit_Product-Age-mean  \
# 6587                               0.618524                40.791607
# 9825                               0.604981                40.791607
# 29143                              0.614125                40.791607
#
#        Credit_Product-Age-median  Credit_Product-Age-std  \
# 6587                          35               14.753063
# 9825                          35               14.753063
# 29143                         35               14.753063
#
#        Credit_Product-Vintage-mean  Credit_Product-Vintage-median  \
# 6587                     40.581871                             27
# 9825                     40.581871                             27
# 29143                    40.581871                             27
#
#        Credit_Product-Vintage-std  Credit_Product-Avg_Account_Balance-mean  \
# 6587                    28.885153                                13.684008
# 9825                    28.885153                                13.684008
# 29143                   28.885153                                13.684008
#
#        Credit_Product-Avg_Account_Balance-median  \
# 6587                                   13.647863
# 9825                                   13.647863
# 29143                                  13.647863
#
#        Credit_Product-Avg_Account_Balance-std  Is_Active-Age-mean  \
# 6587                                 0.624317           41.285321
# 9825                                 0.624317           47.923203
# 29143                                0.624317           41.285321
#
#        Is_Active-Age-median  Is_Active-Age-std  Is_Active-Vintage-mean  \
# 6587                     36          14.618073               41.567754
# 9825                     48          14.217695               55.489554
# 29143                    36          14.618073               41.567754
#
#        Is_Active-Vintage-median  Is_Active-Vintage-std  \
# 6587                         31              29.540018
# 9825                         51              34.657305
# 29143                        31              29.540018
#
#        Is_Active-Avg_Account_Balance-mean  \
# 6587                            13.690874
# 9825                            13.802428
# 29143                           13.690874
#
#        Is_Active-Avg_Account_Balance-median  \
# 6587                              13.659566
# 9825                              13.781543
# 29143                             13.659566
#
#        Is_Active-Avg_Account_Balance-std  Gender-Region_Code-Age-mean  \
# 6587                            0.612792                    36.027363
# 9825                            0.625565                    50.099778
# 29143                           0.612792                    45.979602
#
#        Gender-Region_Code-Age-median  Gender-Region_Code-Age-std  \
# 6587                            31.0                   12.357595
# 9825                            49.0                   13.653215
# 29143                           47.0                   14.692460
#
#        Gender-Region_Code-Vintage-mean  Gender-Region_Code-Vintage-median  \
# 6587                         32.920398                               26.0
# 9825                         61.784858                               62.0
# 29143                        52.321858                               38.0
#
#        Gender-Region_Code-Vintage-std  \
# 6587                        22.533175
# 9825                        33.889134
# 29143                       34.365724
#
#        Gender-Region_Code-Avg_Account_Balance-mean  \
# 6587                                     13.478702
# 9825                                     14.025825
# 29143                                    14.000739
#
#        Gender-Region_Code-Avg_Account_Balance-median  \
# 6587                                       13.434394
# 9825                                       14.017518
# 29143                                      13.976548
#
#        Gender-Region_Code-Avg_Account_Balance-std  Gender-Occupation-Age-mean  \
# 6587                                     0.572737                   30.233873
# 9825                                     0.592916                   55.304334
# 29143                                    0.558210                   47.293512
#
#        Gender-Occupation-Age-median  Gender-Occupation-Age-std  \
# 6587                             29                   5.548506
# 9825                             60                  17.651923
# 29143                            48                   8.392542
#
#        Gender-Occupation-Vintage-mean  Gender-Occupation-Vintage-median  \
# 6587                        24.825372                                21
# 9825                        59.464858                                57
# 29143                       57.670355                                56
#
#        Gender-Occupation-Vintage-std  \
# 6587                       13.665404
# 9825                       34.764459
# 29143                      32.912512
#
#        Gender-Occupation-Avg_Account_Balance-mean  \
# 6587                                    13.615808
# 9825                                    13.818952
# 29143                                   13.738429
#
#        Gender-Occupation-Avg_Account_Balance-median  \
# 6587                                      13.580002
# 9825                                      13.796086
# 29143                                     13.716965
#
#        Gender-Occupation-Avg_Account_Balance-std  \
# 6587                                    0.613589
# 9825                                    0.625990
# 29143                                   0.605444
#
#        Gender-Channel_Code-Age-mean  Gender-Channel_Code-Age-median  ...  \
# 6587                      31.947681                              29  ...
# 9825                      50.582740                              49  ...
# 29143                     55.332957                              54  ...
#
#        Gender-Credit_Product-Avg_Account_Balance-std  \
# 6587                                        0.622490
# 9825                                        0.625067
# 29143                                       0.625067
#
#        Gender-Is_Active-Age-mean  Gender-Is_Active-Age-median  \
# 6587                   38.938101                           32
# 9825                   49.342086                           49
# 29143                  43.444031                           42
#
#        Gender-Is_Active-Age-std  Gender-Is_Active-Vintage-mean  \
# 6587                  14.012360                      37.094897
# 9825                  13.601337                      59.018389
# 29143                 14.829476                      45.681388
#
#        Gender-Is_Active-Vintage-median  Gender-Is_Active-Vintage-std  \
# 6587                                27                     26.671735
# 9825                                57                     34.934066
# 29143                               32                     31.394054
#
#        Gender-Is_Active-Avg_Account_Balance-mean  \
# 6587                                   13.663994
# 9825                                   13.801728
# 29143                                  13.715595
#
#        Gender-Is_Active-Avg_Account_Balance-median  \
# 6587                                     13.626670
# 9825                                     13.781203
# 29143                                    13.689432
#
#        Gender-Is_Active-Avg_Account_Balance-std  \
# 6587                                   0.615316
# 9825                                   0.625037
# 29143                                  0.609421
#
#        Region_Code-Occupation-Age-mean  Region_Code-Occupation-Age-median  \
# 6587                         29.981754                               29.0
# 9825                         58.967986                               63.0
# 29143                        46.988973                               48.0
#
#        Region_Code-Occupation-Age-std  Region_Code-Occupation-Vintage-mean  \
# 6587                         4.935144                            24.685251
# 9825                        16.352660                            65.572662
# 29143                        8.859679                            55.804968
#
#        Region_Code-Occupation-Vintage-median  \
# 6587                                    25.0
# 9825                                    68.0
# 29143                                   51.0
#
#        Region_Code-Occupation-Vintage-std  \
# 6587                            11.667111
# 9825                            33.636895
# 29143                           33.096100
#
#        Region_Code-Occupation-Avg_Account_Balance-mean  \
# 6587                                         13.450863
# 9825                                         14.075728
# 29143                                        13.950268
#
#        Region_Code-Occupation-Avg_Account_Balance-median  \
# 6587                                           13.411802
# 9825                                           14.077804
# 29143                                          13.928111
#
#        Region_Code-Occupation-Avg_Account_Balance-std  \
# 6587                                         0.554358
# 9825                                         0.595842
# 29143                                        0.550486
#
#        Region_Code-Channel_Code-Age-mean  Region_Code-Channel_Code-Age-median  \
# 6587                           30.018583                                 29.0
# 9825                           50.416812                                 49.0
# 29143                          55.134468                                 54.0
#
#        Region_Code-Channel_Code-Age-std  \
# 6587                           5.191595
# 9825                          11.302582
# 29143                         12.039841
#
#        Region_Code-Channel_Code-Vintage-mean  \
# 6587                               23.726157
# 9825                               57.207332
# 29143                              75.378735
#
#        Region_Code-Channel_Code-Vintage-median  \
# 6587                                      25.0
# 9825                                      61.0
# 29143                                     80.0
#
#        Region_Code-Channel_Code-Vintage-std  \
# 6587                               7.610086
# 9825                              27.273778
# 29143                             33.716311
#
#        Region_Code-Channel_Code-Avg_Account_Balance-mean  \
# 6587                                           13.451952
# 9825                                           13.989698
# 29143                                          14.048134
#
#        Region_Code-Channel_Code-Avg_Account_Balance-median  \
# 6587                                           13.415845
# 9825                                           13.976631
# 29143                                          14.015050
#
#        Region_Code-Channel_Code-Avg_Account_Balance-std  \
# 6587                                           0.558613
# 9825                                           0.591709
# 29143                                          0.549842
#
#        Region_Code-Credit_Product-Age-mean  \
# 6587                             35.709906
# 9825                             46.264987
# 29143                            41.020341
#
#        Region_Code-Credit_Product-Age-median  \
# 6587                                    30.0
# 9825                                    46.0
# 29143                                   35.0
#
#        Region_Code-Credit_Product-Age-std  \
# 6587                            12.479160
# 9825                            15.044316
# 29143                           14.830789
#
#        Region_Code-Credit_Product-Vintage-mean  \
# 6587                                 32.084021
# 9825                                 51.727422
# 29143                                41.716909
#
#        Region_Code-Credit_Product-Vintage-median  \
# 6587                                        26.0
# 9825                                        44.0
# 29143                                       27.0
#
#        Region_Code-Credit_Product-Vintage-std  \
# 6587                                22.314507
# 9825                                32.348306
# 29143                               29.775013
#
#        Region_Code-Credit_Product-Avg_Account_Balance-mean  \
# 6587                                           13.458884
# 9825                                           13.992441
# 29143                                          13.979975
#
#        Region_Code-Credit_Product-Avg_Account_Balance-median  \
# 6587                                           13.430862
# 9825                                           13.984893
# 29143                                          13.949191
#
#        Region_Code-Credit_Product-Avg_Account_Balance-std  \
# 6587                                            0.564979
# 9825                                            0.610751
# 29143                                           0.566093
#
#        Region_Code-Is_Active-Age-mean  Region_Code-Is_Active-Age-median  \
# 6587                        36.404920                              31.0
# 9825                        49.036115                              49.0
# 29143                       41.556842                              37.0
#
#        Region_Code-Is_Active-Age-std  Region_Code-Is_Active-Vintage-mean  \
# 6587                       12.686058                           32.931730
# 9825                       13.960779                           60.797907
# 29143                      14.632986                           43.260592
#
#        Region_Code-Is_Active-Vintage-median  \
# 6587                                     26
# 9825                                     62
# 29143                                    27
#
#        Region_Code-Is_Active-Vintage-std  \
# 6587                           23.148247
# 9825                           35.186266
# 29143                          30.415394
#
#        Region_Code-Is_Active-Avg_Account_Balance-mean  \
# 6587                                        13.477788
# 9825                                        14.020491
# 29143                                       13.988598
#
#        Region_Code-Is_Active-Avg_Account_Balance-median  \
# 6587                                          13.437028
# 9825                                          14.017926
# 29143                                         13.962556
#
#        Region_Code-Is_Active-Avg_Account_Balance-std  \
# 6587                                        0.561844
# 9825                                        0.602234
# 29143                                       0.556208
#
#        Occupation-Channel_Code-Age-mean  Occupation-Channel_Code-Age-median  \
# 6587                          29.342995                                  29
# 9825                          59.442674                                  62
# 29143                         50.100950                                  51
#
#        Occupation-Channel_Code-Age-std  Occupation-Channel_Code-Vintage-mean  \
# 6587                          3.403885                             22.884158
# 9825                         13.895012                             58.589195
# 29143                         6.705361                             73.301676
#
#        Occupation-Channel_Code-Vintage-median  \
# 6587                                     21.0
# 9825                                     61.0
# 29143                                    79.0
#
#        Occupation-Channel_Code-Vintage-std  \
# 6587                              7.426934
# 9825                             27.653358
# 29143                            32.354135
#
#        Occupation-Channel_Code-Avg_Account_Balance-mean  \
# 6587                                          13.621987
# 9825                                          13.804688
# 29143                                         13.825329
#
#        Occupation-Channel_Code-Avg_Account_Balance-median  \
# 6587                                           13.584699
# 9825                                           13.785444
# 29143                                          13.810187
#
#        Occupation-Channel_Code-Avg_Account_Balance-std  \
# 6587                                          0.611982
# 9825                                          0.612041
# 29143                                         0.605881
#
#        Occupation-Credit_Product-Age-mean  \
# 6587                            29.560430
# 9825                            49.624410
# 29143                           45.354059
#
#        Occupation-Credit_Product-Age-median  \
# 6587                                     29
# 9825                                     48
# 29143                                    47
#
#        Occupation-Credit_Product-Age-std  \
# 6587                            3.889061
# 9825                           19.664724
# 29143                           9.352548
#
#        Occupation-Credit_Product-Vintage-mean  \
# 6587                                23.426746
# 9825                                48.276304
# 29143                               51.904785
#
#        Occupation-Credit_Product-Vintage-median  \
# 6587                                         21
# 9825                                         33
# 29143                                        49
#
#        Occupation-Credit_Product-Vintage-std  \
# 6587                                9.253663
# 9825                               32.204767
# 29143                              31.022695
#
#        Occupation-Credit_Product-Avg_Account_Balance-mean  \
# 6587                                           13.619111
# 9825                                           13.741391
# 29143                                          13.705602
#
#        Occupation-Credit_Product-Avg_Account_Balance-median  \
# 6587                                           13.579394
# 9825                                           13.710649
# 29143                                          13.672885
#
#        Occupation-Credit_Product-Avg_Account_Balance-std  \
# 6587                                            0.617434
# 9825                                            0.635718
# 29143                                           0.616762
#
#        Occupation-Is_Active-Age-mean  Occupation-Is_Active-Age-median  \
# 6587                       30.476931                               29
# 9825                       57.710886                               62
# 29143                      45.697397                               47
#
#        Occupation-Is_Active-Age-std  Occupation-Is_Active-Vintage-mean  \
# 6587                       5.708913                          25.479779
# 9825                      16.796927                          63.298919
# 29143                      9.279214                          52.037951
#
#        Occupation-Is_Active-Vintage-median  Occupation-Is_Active-Vintage-std  \
# 6587                                    25                         14.052418
# 9825                                    63                         34.958821
# 29143                                   49                         31.448600
#
#        Occupation-Is_Active-Avg_Account_Balance-mean  \
# 6587                                       13.602420
# 9825                                       13.857741
# 29143                                      13.723480
#
#        Occupation-Is_Active-Avg_Account_Balance-median  \
# 6587                                         13.567376
# 9825                                         13.839231
# 29143                                        13.698787
#
#        Occupation-Is_Active-Avg_Account_Balance-std  \
# 6587                                       0.607033
# 9825                                       0.633392
# 29143                                      0.597698
#
#        Channel_Code-Credit_Product-Age-mean  \
# 6587                              31.437029
# 9825                              50.699305
# 29143                             55.160681
#
#        Channel_Code-Credit_Product-Age-median  \
# 6587                                       29
# 9825                                       49
# 29143                                      54
#
#        Channel_Code-Credit_Product-Age-std  \
# 6587                              8.277654
# 9825                             11.595563
# 29143                            12.968310
#
#        Channel_Code-Credit_Product-Vintage-mean  \
# 6587                                  24.406913
# 9825                                  53.602277
# 29143                                 72.752381
#
#        Channel_Code-Credit_Product-Vintage-median  \
# 6587                                           25
# 9825                                           55
# 29143                                          74
#
#        Channel_Code-Credit_Product-Vintage-std  \
# 6587                                 10.435279
# 9825                                 26.623489
# 29143                                32.049188
#
#        Channel_Code-Credit_Product-Avg_Account_Balance-mean  \
# 6587                                           13.622954
# 9825                                           13.728676
# 29143                                          13.810513
#
#        Channel_Code-Credit_Product-Avg_Account_Balance-median  \
# 6587                                           13.581629
# 9825                                           13.700990
# 29143                                          13.787153
#
#        Channel_Code-Credit_Product-Avg_Account_Balance-std  \
# 6587                                            0.618630
# 9825                                            0.618954
# 29143                                           0.624411
#
#        Channel_Code-Is_Active-Age-mean  Channel_Code-Is_Active-Age-median  \
# 6587                         31.905289                                 29
# 9825                         50.028448                                 48
# 29143                        54.145345                                 53
#
#        Channel_Code-Is_Active-Age-std  Channel_Code-Is_Active-Vintage-mean  \
# 6587                         8.829930                            24.890678
# 9825                        11.195013                            53.959872
# 29143                       12.732743                            70.575908
#
#        Channel_Code-Is_Active-Vintage-median  \
# 6587                                      25
# 9825                                      55
# 29143                                     74
#
#        Channel_Code-Is_Active-Vintage-std  \
# 6587                            10.778658
# 9825                            28.684730
# 29143                           33.149403
#
#        Channel_Code-Is_Active-Avg_Account_Balance-mean  \
# 6587                                         13.599267
# 9825                                         13.748476
# 29143                                        13.845411
#
#        Channel_Code-Is_Active-Avg_Account_Balance-median  \
# 6587                                           13.562733
# 9825                                           13.727760
# 29143                                          13.829655
#
#        Channel_Code-Is_Active-Avg_Account_Balance-std  \
# 6587                                         0.608134
# 9825                                         0.617820
# 29143                                        0.606719
#
#        Credit_Product-Is_Active-Age-mean  Credit_Product-Is_Active-Age-median  \
# 6587                           37.114239                                   31
# 9825                           46.009136                                   46
# 29143                          37.114239                                   31
#
#        Credit_Product-Is_Active-Age-std  \
# 6587                          13.289813
# 9825                          15.148168
# 29143                         13.289813
#
#        Credit_Product-Is_Active-Vintage-mean  \
# 6587                               35.176062
# 9825                               48.251750
# 29143                              35.176062
#
#        Credit_Product-Is_Active-Vintage-median  \
# 6587                                        27
# 9825                                        33
# 29143                                       27
#
#        Credit_Product-Is_Active-Vintage-std  \
# 6587                              24.514767
# 9825                              32.637442
# 29143                             24.514767
#
#        Credit_Product-Is_Active-Avg_Account_Balance-mean  \
# 6587                                           13.627760
# 9825                                           13.763813
# 29143                                          13.627760
#
#        Credit_Product-Is_Active-Avg_Account_Balance-median  \
# 6587                                           13.589475
# 9825                                           13.738150
# 29143                                          13.589475
#
#        Credit_Product-Is_Active-Avg_Account_Balance-std
# 6587                                           0.613927
# 9825                                           0.630220
# 29143                                          0.613927
#
# [3 rows x 215 columns]

# %%
x_train = train.drop(['ID','Is_Lead'],axis=1)
y_train = train['Is_Lead']

x_valid = valid.drop(['ID','Is_Lead'],axis=1)
y_valid = valid['Is_Lead']

x_test = test.drop(['ID'],axis=1)

# %%
x_train = x_train.fillna(0)
x_valid = x_valid.fillna(0)
x_test = x_test.fillna(0)

# %%
lgb_params= {'learning_rate': 0.05, 
             'n_estimators': 500, 
             'max_bin': 100,
             'num_leaves': 10, 
             'max_depth': 30, 
             'reg_alpha': 8.5, 
             'reg_lambda': 7.0, 
             'subsample': 0.75,
            'random_state': 42,
            'class_weight':'balanced'}


lgb = LGBMClassifier(**lgb_params)
lgb.fit(x_train, y_train,eval_set=[(x_valid, y_valid)],early_stopping_rounds=10,verbose=400)
pred = lgb.predict_proba(x_valid)[:, 1]
roc_score = roc_auc_score(y_valid, pred)
print(f"roc_auc_score: {roc_score}")
# Out:
# Training until validation scores don't improve for 10 rounds
# [400]	valid_0's binary_logloss: 0.422714
# Early stopping, best iteration is:
# [472]	valid_0's binary_logloss: 0.422459
# roc_auc_score: 0.8733204076195035

# %%
xgb_params= {'n_estimators': 500, 
             'max_depth': 5, 
             'learning_rate': 0.02, 
             'reg_lambda': 29, 
             'subsample': 0.80, 
             'colsample_bytree': 0.25, 
             'colsample_bynode': 0.80, 
             'colsample_bylevel': 0.5,
            'random_state':42,
            'use_label_encoder':False }


xgb = XGBClassifier(**xgb_params)
xgb.fit(x_train, y_train,eval_set=[(x_valid, y_valid)],early_stopping_rounds=10,verbose=400)
pred = xgb.predict_proba(x_valid)[:, 1]
roc_score = roc_auc_score(y_valid, pred)
print(f"roc_auc_score: {roc_score}")
# Out:
# [15:25:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.68217
# [400]	validation_0-logloss:0.34840
# [499]	validation_0-logloss:0.34752
# roc_auc_score: 0.8715869800266962

# %%
cat_params= {'n_estimators': 500, 
            'depth': 5, 
            'learning_rate': 0.02, 
            'colsample_bylevel': 0.70, 
            'bagging_temperature': 0.90, 
            'l2_leaf_reg': 10,
            'random_seed': 23}

cat = CatBoostClassifier(**cat_params)
cat.fit(x_train, y_train,eval_set=[(x_valid, y_valid)],early_stopping_rounds=10,verbose=400)
pred = cat.predict_proba(x_valid)[:, 1]
roc_score = roc_auc_score(y_valid, pred)
print(f"roc_auc_score: {roc_score}")
# Out:
# 0:	learn: 0.6760811	test: 0.6761160	best: 0.6761160 (0)	total: 504ms	remaining: 4m 11s
# 400:	learn: 0.3435602	test: 0.3465535	best: 0.3465535 (400)	total: 1m 3s	remaining: 15.7s
# 499:	learn: 0.3429350	test: 0.3462430	best: 0.3462430 (499)	total: 1m 18s	remaining: 0us
#
# bestTest = 0.3462429726
# bestIteration = 499
#
# roc_auc_score: 0.872413181694604

# %%
ada_params= {'n_estimators': 200, 
            'learning_rate': 0.08, 
            'random_state': 23}

ada = AdaBoostClassifier(**ada_params)
ada.fit(x_train,y_train)
pred = ada.predict_proba(x_valid)[:, 1]
roc_score = roc_auc_score(y_valid, pred)
print(f"roc_auc_score: {roc_score}")
# Out:
# roc_auc_score: 0.865400087710626

# %%
grad_params = {'n_estimators':100,
               'learning_rate' : 0.08,
               'subsample' : 0.7,
               'random_state' : 45,
               'max_features' : 'auto',
               'verbose':1
              }


grad = GradientBoostingClassifier(**grad_params)
grad.fit(x_train,y_train)
pred = grad.predict_proba(x_valid)[:, 1]
roc_score = roc_auc_score(y_valid, pred)
print(f"roc_auc_score: {roc_score}")
# Out:
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1           1.0336           0.0587            3.84m
#          2           0.9909           0.0463            3.76m
#          3           0.9522           0.0377            3.72m
#          4           0.9210           0.0309            3.67m
#          5           0.8953           0.0261            3.63m
#          6           0.8732           0.0222            3.60m
#          7           0.8527           0.0193            3.56m
#          8           0.8371           0.0166            3.52m
#          9           0.8215           0.0144            3.48m
#         10           0.8109           0.0124            3.44m
#         20           0.7419           0.0037            3.14m
#         30           0.7152           0.0020            2.74m
#         40           0.7067           0.0006            2.35m
#         50           0.7031           0.0005            1.98m
#         60           0.6938           0.0003            1.59m
#         70           0.6915           0.0001            1.19m
#         80           0.6922           0.0000           47.63s
#         90           0.6911           0.0001           23.81s
#        100           0.6884          -0.0000            0.00s
# roc_auc_score: 0.8717381778642606

# %%
hist_params = {'max_iter':500,
               'learning_rate' : 0.06,
               'max_depth' : 7,
               'early_stopping' : 'auto',
               'verbose':1,
               'random_state':63
              }


hist = HistGradientBoostingClassifier(**hist_params)
hist.fit(x_train,y_train)
pred = hist.predict_proba(x_valid)[:, 1]
roc_score = roc_auc_score(y_valid, pred)
print(f"roc_auc_score: {roc_score}")
# Out:
# Binning 0.301 GB of training data: 2.823 s
# Binning 0.033 GB of validation data: 0.047 s
# Fitting gradient boosted rounds:
# [1/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.52359, val loss: 0.52335, in 0.193s
# [2/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.50351, val loss: 0.50320, in 0.213s
# [3/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.48647, val loss: 0.48612, in 0.208s
# [4/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.47170, val loss: 0.47134, in 0.207s
# [5/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.45883, val loss: 0.45841, in 0.213s
# [6/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.44749, val loss: 0.44709, in 0.206s
# [7/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.43740, val loss: 0.43701, in 0.230s
# [8/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.42849, val loss: 0.42813, in 0.214s
# [9/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.42045, val loss: 0.42009, in 0.210s
# [10/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.41332, val loss: 0.41299, in 0.210s
# [11/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.40685, val loss: 0.40655, in 0.213s
# [12/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.40110, val loss: 0.40085, in 0.217s
# [13/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.39591, val loss: 0.39568, in 0.201s
# [14/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.39115, val loss: 0.39095, in 0.209s
# [15/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.38687, val loss: 0.38672, in 0.202s
# [16/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.38297, val loss: 0.38284, in 0.217s
# [17/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.37944, val loss: 0.37935, in 0.203s
# [18/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.37627, val loss: 0.37624, in 0.202s
# [19/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.37338, val loss: 0.37336, in 0.215s
# [20/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.37076, val loss: 0.37080, in 0.205s
# [21/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.36836, val loss: 0.36841, in 0.209s
# [22/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.36619, val loss: 0.36626, in 0.207s
# [23/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.36417, val loss: 0.36429, in 0.221s
# [24/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.36234, val loss: 0.36248, in 0.211s
# [25/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.36070, val loss: 0.36088, in 0.226s
# [26/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.35922, val loss: 0.35942, in 0.229s
# [27/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.35776, val loss: 0.35796, in 0.215s
# [28/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.35654, val loss: 0.35677, in 0.221s
# [29/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.35532, val loss: 0.35561, in 0.205s
# [30/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.35419, val loss: 0.35450, in 0.223s
# [31/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.35324, val loss: 0.35358, in 0.222s
# [32/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.35231, val loss: 0.35267, in 0.209s
# [33/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.35150, val loss: 0.35189, in 0.222s
# [34/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.35075, val loss: 0.35115, in 0.222s
# [35/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.35004, val loss: 0.35047, in 0.222s
# [36/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34943, val loss: 0.34989, in 0.229s
# [37/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34881, val loss: 0.34932, in 0.212s
# [38/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34829, val loss: 0.34886, in 0.227s
# [39/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34781, val loss: 0.34842, in 0.227s
# [40/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34731, val loss: 0.34799, in 0.207s
# [41/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34686, val loss: 0.34762, in 0.212s
# [42/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34644, val loss: 0.34727, in 0.200s
# [43/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34606, val loss: 0.34695, in 0.221s
# [44/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34568, val loss: 0.34665, in 0.221s
# [45/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34536, val loss: 0.34640, in 0.223s
# [46/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34506, val loss: 0.34617, in 0.210s
# [47/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34481, val loss: 0.34599, in 0.217s
# [48/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34457, val loss: 0.34580, in 0.242s
# [49/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34434, val loss: 0.34565, in 0.216s
# [50/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34408, val loss: 0.34545, in 0.223s
# [51/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34387, val loss: 0.34531, in 0.209s
# [52/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34365, val loss: 0.34519, in 0.212s
# [53/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34347, val loss: 0.34508, in 0.216s
# [54/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34330, val loss: 0.34494, in 0.203s
# [55/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34315, val loss: 0.34485, in 0.210s
# [56/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34298, val loss: 0.34474, in 0.202s
# [57/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34280, val loss: 0.34463, in 0.209s
# [58/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34263, val loss: 0.34453, in 0.211s
# [59/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34249, val loss: 0.34445, in 0.191s
# [60/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34233, val loss: 0.34435, in 0.209s
# [61/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34218, val loss: 0.34427, in 0.222s
# [62/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34206, val loss: 0.34420, in 0.183s
# [63/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34192, val loss: 0.34413, in 0.196s
# [64/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34179, val loss: 0.34406, in 0.222s
# [65/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34168, val loss: 0.34400, in 0.204s
# [66/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34156, val loss: 0.34393, in 0.202s
# [67/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34144, val loss: 0.34391, in 0.205s
# [68/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34133, val loss: 0.34388, in 0.187s
# [69/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34124, val loss: 0.34385, in 0.188s
# [70/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34116, val loss: 0.34381, in 0.168s
# [71/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34105, val loss: 0.34379, in 0.182s
# [72/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34096, val loss: 0.34379, in 0.179s
# [73/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34084, val loss: 0.34374, in 0.202s
# [74/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34073, val loss: 0.34368, in 0.187s
# [75/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34065, val loss: 0.34367, in 0.168s
# [76/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34054, val loss: 0.34364, in 0.199s
# [77/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34046, val loss: 0.34364, in 0.184s
# [78/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34034, val loss: 0.34360, in 0.198s
# [79/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34024, val loss: 0.34358, in 0.189s
# [80/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34013, val loss: 0.34355, in 0.197s
# [81/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.34004, val loss: 0.34353, in 0.170s
# [82/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33994, val loss: 0.34351, in 0.200s
# [83/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33986, val loss: 0.34351, in 0.166s
# [84/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33978, val loss: 0.34349, in 0.174s
# [85/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33971, val loss: 0.34347, in 0.162s
# [86/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33962, val loss: 0.34344, in 0.190s
# [87/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33953, val loss: 0.34343, in 0.209s
# [88/500] 1 tree, 24 leaves, max depth = 7, train loss: 0.33949, val loss: 0.34343, in 0.149s
# [89/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33942, val loss: 0.34342, in 0.180s
# [90/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33934, val loss: 0.34338, in 0.187s
# [91/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33927, val loss: 0.34340, in 0.125s
# [92/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33919, val loss: 0.34340, in 0.173s
# [93/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33913, val loss: 0.34339, in 0.139s
# [94/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33907, val loss: 0.34340, in 0.175s
# [95/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33900, val loss: 0.34341, in 0.162s
# [96/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33895, val loss: 0.34341, in 0.153s
# [97/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33888, val loss: 0.34341, in 0.146s
# [98/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33883, val loss: 0.34342, in 0.146s
# [99/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33877, val loss: 0.34342, in 0.130s
# [100/500] 1 tree, 31 leaves, max depth = 7, train loss: 0.33871, val loss: 0.34339, in 0.179s
# Fit 100 trees in 23.857 s, (3093 total leaves)
# Time spent computing histograms: 9.880s
# Time spent finding best splits:  0.416s
# Time spent applying splits:      0.605s
# Time spent predicting:           0.046s
# roc_auc_score: 0.8733324344341928

# %%
train_pred = pd.DataFrame()
train_pred['lgb'] = lgb.predict_proba(x_train)[:, 1]
train_pred['xgb'] = xgb.predict_proba(x_train)[:, 1]
train_pred['cat'] = cat.predict_proba(x_train)[:, 1]
train_pred['ada'] = ada.predict_proba(x_train)[:, 1]
train_pred['grad'] = grad.predict_proba(x_train)[:, 1]
train_pred['hist'] = hist.predict_proba(x_train)[:, 1]
train_pred.head(3)
# Out:
#         lgb       xgb       cat       ada      grad      hist
# 0  0.177978  0.072633  0.065084  0.460619  0.059675  0.061099
# 1  0.309638  0.204664  0.173076  0.483216  0.180596  0.136129
# 2  0.783900  0.493995  0.479599  0.494111  0.468828  0.500255

# %%
valid_pred = pd.DataFrame()
valid_pred['lgb'] = lgb.predict_proba(x_valid)[:, 1]
valid_pred['xgb'] = xgb.predict_proba(x_valid)[:, 1]
valid_pred['cat'] = cat.predict_proba(x_valid)[:, 1]
valid_pred['ada'] = ada.predict_proba(x_valid)[:, 1]
valid_pred['grad'] = grad.predict_proba(x_valid)[:, 1]
valid_pred['hist'] = hist.predict_proba(x_valid)[:, 1]
valid_pred.head(3)
# Out:
#         lgb       xgb       cat       ada      grad      hist
# 0  0.146775  0.062817  0.056691  0.458025  0.054826  0.051147
# 1  0.944318  0.834179  0.830782  0.529344  0.835377  0.834074
# 2  0.692287  0.373265  0.429635  0.492200  0.544626  0.412364

# %%
test_pred = pd.DataFrame()
test_pred['lgb'] = lgb.predict_proba(x_test)[:, 1]
test_pred['xgb'] = xgb.predict_proba(x_test)[:, 1]
test_pred['cat'] = cat.predict_proba(x_test)[:, 1]
test_pred['ada'] = ada.predict_proba(x_test)[:, 1]
test_pred['grad'] = grad.predict_proba(x_test)[:, 1]
test_pred['hist'] = hist.predict_proba(x_test)[:, 1]
test_pred.head(3)
# Out:
#         lgb       xgb       cat       ada      grad      hist
# 0  0.115147  0.041271  0.052321  0.461465  0.057002  0.038952
# 1  0.945285  0.854583  0.842623  0.519640  0.849023  0.846096
# 2  0.160164  0.056577  0.052935  0.455125  0.052681  0.053951

# %%
model = LogisticRegression(random_state=10,max_iter=1000,class_weight='balanced',fit_intercept=True)
model.fit(train_pred,y_train)
pred = model.predict_proba(valid_pred)[:, 1]
roc_score = roc_auc_score(y_valid, pred)
print(f"roc_auc_score: {roc_score}")
# Out:
# roc_auc_score: 0.8726312363570534

# %%
pred = valid_pred.mean(axis=1)
roc_score = roc_auc_score(y_valid, pred)
print(f"roc_auc_score: {roc_score}")
# Out:
# roc_auc_score: 0.8730279976786417

# %%
test_pred['stacked_avg'] = test_pred.mean(axis=1)
test_pred['stacked_logistic'] = model.predict_proba(test_pred.drop(['stacked_avg'],axis=1))[:, 1]
test_pred['ID'] = test['ID']
test_pred.head(1)
# Out:
#         lgb       xgb       cat       ada      grad      hist  stacked_avg  \
# 0  0.115147  0.041271  0.052321  0.461465  0.057002  0.038952     0.127693
#
#    stacked_logistic        ID
# 0          0.117788  VBENBARO

# %%
test_pred[['ID','lgb']].rename({'lgb':'Is_Lead'},axis=1).to_csv('LGB_submit_v1.csv',index=False)
test_pred[['ID','xgb']].rename({'xgb':'Is_Lead'},axis=1).to_csv('XGB_submit_v1.csv',index=False)
test_pred[['ID','cat']].rename({'cat':'Is_Lead'},axis=1).to_csv('CAT_submit_v1.csv',index=False)
test_pred[['ID','hist']].rename({'hist':'Is_Lead'},axis=1).to_csv('HIST_submit_v1.csv',index=False)
test_pred[['ID','ada']].rename({'ada':'Is_Lead'},axis=1).to_csv('ADA_submit_v1.csv',index=False)
test_pred[['ID','grad']].rename({'grad':'Is_Lead'},axis=1).to_csv('GRAD_submit_v1.csv',index=False)

test_pred[['ID','stacked_avg']].rename({'stacked_avg':'Is_Lead'},axis=1).to_csv('AVG.csv',index=False)
test_pred[['ID','stacked_logistic']].rename({'stacked_logistic':'Is_Lead'},axis=1).to_csv('LOG.csv',index=False)

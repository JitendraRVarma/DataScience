# %%
# !wget https://datahack-prod.s3.amazonaws.com/train_file/train_0OECtn8.csv
# !wget https://datahack-prod.s3.amazonaws.com/test_file/test_1zqHu22.csv
# Out:
# --2022-02-12 15:10:42--  https://datahack-prod.s3.amazonaws.com/train_file/train_0OECtn8.csv
# Resolving datahack-prod.s3.amazonaws.com (datahack-prod.s3.amazonaws.com)... 52.219.160.79
# Connecting to datahack-prod.s3.amazonaws.com (datahack-prod.s3.amazonaws.com)|52.219.160.79|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4610340 (4.4M) [application/vnd.ms-excel]
# Saving to: ‘train_0OECtn8.csv.4’
#
# train_0OECtn8.csv.4 100%[===================>]   4.40M   724KB/s    in 9.7s
#
# 2022-02-12 15:10:53 (462 KB/s) - ‘train_0OECtn8.csv.4’ saved [4610340/4610340]
#
# --2022-02-12 15:10:53--  https://datahack-prod.s3.amazonaws.com/test_file/test_1zqHu22.csv
# Resolving datahack-prod.s3.amazonaws.com (datahack-prod.s3.amazonaws.com)... 52.219.66.84
# Connecting to datahack-prod.s3.amazonaws.com (datahack-prod.s3.amazonaws.com)|52.219.66.84|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 503967 (492K) [application/vnd.ms-excel]
# Saving to: ‘test_1zqHu22.csv.3’
#
# test_1zqHu22.csv.3  100%[===================>] 492.16K   390KB/s    in 1.3s
#
# 2022-02-12 15:10:55 (390 KB/s) - ‘test_1zqHu22.csv.3’ saved [503967/503967]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import seaborn as sns

from sklearn.dummy import DummyRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score,make_scorer
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
import xgboost as xgb
import lightgbm as lgb

# %%
raw_train = pd.read_csv("train_0OECtn8.csv")
raw_test = pd.read_csv("test_1zqHu22.csv")

# %%
print(f"Train shape {raw_train.shape}, Test shape {raw_test.shape}")
# Out:
# Train shape (89197, 10), Test shape (11121, 9)

# %%
raw_train.head(3)
# Out:
#    row_id  user_id  category_id  ...  followers  views engagement_score
# 0       1    19990           37  ...        180   1000             4.33
# 1       2     5304           32  ...        330    714             1.79
# 2       3     1840           12  ...        180    138             4.35
#
# [3 rows x 10 columns]

# %%
raw_train.tail(3)
# Out:
#        row_id  user_id  category_id  ...  followers  views engagement_score
# 89194   89195    13655           16  ...        270    462             4.23
# 89195   89196    24840            9  ...        230    819             3.77
# 89196   89197    27183           25  ...        240    317             4.31
#
# [3 rows x 10 columns]

# %%
raw_test.head(3)
# Out:
#    row_id  user_id  category_id  ...            profession  followers views
# 0   89198     7986           12  ...               Student        180   138
# 1   89199    11278           34  ...               Student        230   840
# 2   89200    17245            8  ...  Working Professional        280   628
#
# [3 rows x 9 columns]

# %%
raw_test.tail(3)
# Out:
#        row_id  user_id  category_id  ...            profession  followers views
# 11118  100316     2042           16  ...               Student        270   462
# 11119  100317    24626            8  ...                 Other        280   628
# 11120  100318      967            8  ...  Working Professional        280   628
#
# [3 rows x 9 columns]

# %%
raw_train.isna().sum()
# Out:
# row_id              0
# user_id             0
# category_id         0
# video_id            0
# age                 0
# gender              0
# profession          0
# followers           0
# views               0
# engagement_score    0
# dtype: int64

# %%
raw_test.isna().sum()
# Out:
# row_id         0
# user_id        0
# category_id    0
# video_id       0
# age            0
# gender         0
# profession     0
# followers      0
# views          0
# dtype: int64

# %%
raw_train.describe()
# Out:
#              row_id       user_id  ...         views  engagement_score
# count  89197.000000  89197.000000  ...  89197.000000      89197.000000
# mean   44599.000000  13881.909806  ...    502.980268          3.487797
# std    25749.100318   8005.582771  ...    268.569482          0.863498
# min        1.000000      1.000000  ...     30.000000          0.000000
# 25%    22300.000000   6945.000000  ...    229.000000          2.900000
# 50%    44599.000000  13892.000000  ...    467.000000          3.710000
# 75%    66898.000000  20819.000000  ...    714.000000          4.150000
# max    89197.000000  27734.000000  ...   1000.000000          5.000000
#
# [8 rows x 8 columns]

# %%
raw_train.describe(include=np.object)
# Out:
#        gender profession
# count   89197      89197
# unique      2          3
# top      Male    Student
# freq    52397      44638

# %%
raw_train['user_id'].value_counts().min(),raw_train['user_id'].value_counts().max()
# Out:
# (2, 10)

# %%
raw_train['user_id'].value_counts().head(3)
# Out:
# 5198     10
# 13218    10
# 1448     10
# Name: user_id, dtype: int64

# %%
raw_train[raw_train['user_id']==5198]
# Out:
#        row_id  user_id  category_id  ...  followers  views engagement_score
# 22708   22709     5198            5  ...        240    229             4.30
# 28089   28090     5198            5  ...        240    229             4.60
# 32687   32688     5198            5  ...        240    229             4.50
# 33424   33425     5198            5  ...        240    229             4.28
# 35305   35306     5198            5  ...        240    229             4.26
# 48919   48920     5198            5  ...        240    229             4.47
# 62534   62535     5198            5  ...        240    229             4.13
# 73528   73529     5198            5  ...        240    229             4.44
# 79107   79108     5198            5  ...        240    229             4.51
# 85219   85220     5198            5  ...        240    229             4.44
#
# [10 rows x 10 columns]

# %%
common_user_id = set(raw_train['user_id'].unique()).intersection(set(raw_test['user_id'].unique()))
len(common_user_id)
# Out:
# 10384

# %%
raw_train['user_id'].nunique(), raw_test['user_id'].nunique()
# Out:
# (27734, 10384)

# %%
raw_train['category_id'].value_counts(normalize=True).sort_index()
# Out:
# 1     0.020292
# 2     0.001872
# 3     0.020685
# 4     0.041235
# 5     0.090855
# 6     0.015684
# 7     0.021133
# 8     0.070776
# 9     0.021144
# 10    0.013644
# 11    0.042221
# 12    0.043600
# 13    0.031133
# 14    0.006009
# 15    0.024261
# 16    0.036593
# 17    0.013543
# 18    0.025124
# 19    0.052457
# 20    0.007870
# 21    0.045327
# 22    0.004103
# 23    0.029945
# 24    0.005875
# 25    0.054710
# 26    0.012960
# 27    0.012366
# 28    0.014675
# 29    0.010269
# 30    0.006144
# 31    0.020797
# 32    0.030405
# 33    0.005796
# 34    0.036963
# 35    0.011054
# 36    0.011491
# 37    0.010785
# 38    0.005987
# 39    0.015012
# 40    0.005135
# 41    0.006110
# 42    0.024418
# 43    0.011424
# 44    0.002399
# 45    0.002545
# 46    0.002646
# 47    0.000527
# Name: category_id, dtype: float64

# %%
raw_train['video_id'].value_counts(normalize=False).head(10)
# Out:
# 112    1337
# 53     1334
# 1      1282
# 65     1103
# 42     1077
# 46      938
# 4       932
# 10      921
# 5       913
# 87      902
# Name: video_id, dtype: int64

# %%
raw_train[raw_train['video_id']==10]
# Out:
#        row_id  user_id  category_id  ...  followers  views engagement_score
# 115       116      476            5  ...        240    229             2.48
# 181       182    16877            5  ...        240    229             3.22
# 214       215    13064            5  ...        240    229             2.30
# 357       358    25281            5  ...        240    229             3.80
# 399       400     3718            5  ...        240    229             4.57
# ...       ...      ...          ...  ...        ...    ...              ...
# 88844   88845    16113            5  ...        240    229             2.80
# 88901   88902    21712            5  ...        240    229             3.64
# 89066   89067    17572            5  ...        240    229             3.62
# 89133   89134    26217            5  ...        240    229             2.19
# 89182   89183     9995            5  ...        240    229             4.60
#
# [921 rows x 10 columns]

# %%
raw_test[raw_test['video_id']==10]
# Out:
#        row_id  user_id  category_id  ...            profession  followers views
# 51      89249     4033            5  ...  Working Professional        240   229
# 92      89290    25610            5  ...  Working Professional        240   229
# 285     89483    19113            5  ...               Student        240   229
# 362     89560    15928            5  ...                 Other        240   229
# 371     89569     8313            5  ...                 Other        240   229
# ...       ...      ...          ...  ...                   ...        ...   ...
# 10901  100099     5556            5  ...  Working Professional        240   229
# 11013  100211     8865            5  ...  Working Professional        240   229
# 11039  100237    18756            5  ...                 Other        240   229
# 11050  100248     4483            5  ...                 Other        240   229
# 11094  100292    23876            5  ...                 Other        240   229
#
# [131 rows x 9 columns]

# %%
raw_test[raw_test['video_id']==1].sort_values(by='user_id')
# Out:
#       row_id  user_id  category_id  ...            profession  followers views
# 56     89254       16           19  ...               Student        230   369
# 5032   94230       78            1  ...               Student        360   990
# 9168   98366      362           19  ...                 Other        230   369
# 9474   98672     1041           19  ...               Student        230   369
# 5133   94331     1080           19  ...                 Other        230   369
# ...      ...      ...          ...  ...                   ...        ...   ...
# 8440   97638    27347            1  ...                 Other        360   990
# 7058   96256    27390            1  ...               Student        360   990
# 1418   90616    27479           19  ...  Working Professional        230   369
# 9950   99148    27501           19  ...               Student        230   369
# 1739   90937    27679           19  ...  Working Professional        230   369
#
# [232 rows x 9 columns]

# %%
raw_train[raw_train['video_id']==1].sort_values(by='user_id')
# Out:
#        row_id  user_id  category_id  ...  followers  views engagement_score
# 30684   30685        1            1  ...        360    990             2.88
# 82236   82237       10            1  ...        360    990             2.70
# 1105     1106       36           19  ...        230    369             4.25
# 10818   10819       51           19  ...        230    369             4.29
# 43691   43692       56            1  ...        360    990             2.30
# ...       ...      ...          ...  ...        ...    ...              ...
# 68490   68491    27663            1  ...        360    990             3.32
# 51117   51118    27669           19  ...        230    369             4.21
# 34829   34830    27691           19  ...        230    369             3.81
# 75844   75845    27696            1  ...        360    990             4.25
# 44822   44823    27698            1  ...        360    990             4.39
#
# [1282 rows x 10 columns]

# %%
raw_train.groupby(['video_id'])[['followers','views','category_id']].std()
# Out:
#           followers       views  category_id
# video_id
# 1         64.827241  309.674744      8.97608
# 2          0.000000    0.000000      0.00000
# 3          0.000000    0.000000      0.00000
# 4          0.000000    0.000000      0.00000
# 5          0.000000    0.000000      0.00000
# ...             ...         ...          ...
# 171        0.000000    0.000000      0.00000
# 172        0.000000    0.000000      0.00000
# 173        0.000000    0.000000      0.00000
# 174        0.000000    0.000000      0.00000
# 175        0.000000    0.000000      0.00000
#
# [175 rows x 3 columns]

# %%
raw_train.groupby(['user_id'])[['followers','views','category_id']].std()
# Out:
#           followers       views  category_id
# user_id
# 1         80.829038  554.256258     0.577350
# 2         21.908902   87.635609     0.547723
# 3         17.320508   76.787586     0.577350
# 4        115.470054  301.954191     3.464102
# 5         28.867513  110.273901     0.577350
# ...             ...         ...          ...
# 27730     57.735027   72.746134     1.154701
# 27731     14.142136  144.249783     1.414214
# 27732      0.000000    0.000000     0.000000
# 27733     34.641016    0.000000     2.886751
# 27734      0.000000    0.000000     0.000000
#
# [27734 rows x 3 columns]

# %%
raw_train['video_id'].nunique(),raw_test['video_id'].nunique()
# Out:
# (175, 128)

# %%
common_video_id = set(raw_train['video_id'].unique()).intersection(set(raw_test['video_id'].unique()))
len(common_video_id)
# Out:
# 128

# %%
raw_train.groupby(['video_id'])['category_id'].nunique().describe()
# Out:
# count    175.000000
# mean       1.005714
# std        0.075593
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000
# Name: category_id, dtype: float64

# %%
raw_train.groupby(['user_id'])['profession'].nunique().describe()
# Out:
# count    27734.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
# Name: profession, dtype: float64

# %%
df = pd.concat([raw_train,raw_test],axis=0,ignore_index=True,sort=False)
df.shape[0] == raw_train.shape[0]+raw_test.shape[0]
# Out:
# True

# %%
df.sample(3)
# Out:
#        row_id  user_id  category_id  ...  followers  views engagement_score
# 57960   57961    13852            7  ...        160    467             2.64
# 25913   25914    13577            3  ...        270    621             3.73
# 45509   45510    13469            8  ...        280    628             3.69
#
# [3 rows x 10 columns]

# %%
df['category_id'].nunique(),df['video_id'].nunique()
# Out:
# (47, 175)

# %%
base_score = df['engagement_score'].mean()
base_score
# Out:
# 3.487797011110046

# %%
def cv(x):
    return np.mean(x)/base_score

# %%
user_profile = df.groupby(['user_id']).agg({'category_id':pd.Series.nunique,
                                            'video_id':pd.Series.nunique,
                                            'views':['mean','sum','std','count'],
                                            'followers':['mean','sum','std'],
                                            'engagement_score': cv,
                                            })

user_profile.columns = ["_".join(x) for x in user_profile.columns]
user_profile =user_profile.add_suffix("_usr")
user_profile = user_profile.reset_index()
user_profile.describe()
# Out:
#             user_id  ...  engagement_score_cv_usr
# count  27734.000000  ...             27734.000000
# mean   13867.500000  ...                 0.999011
# std     8006.260519  ...                 0.204981
# min        1.000000  ...                 0.000000
# 25%     6934.250000  ...                 0.872566
# 50%    13867.500000  ...                 1.028347
# 75%    20800.750000  ...                 1.147811
# max    27734.000000  ...                 1.433570
#
# [8 rows x 11 columns]

# %%
user_profile.sample(3)
# Out:
#        user_id  ...  engagement_score_cv_usr
# 18180    18181  ...                 1.242905
# 3708      3709  ...                 1.256763
# 8640      8641  ...                 1.186996
#
# [3 rows x 11 columns]

# %%
df.groupby(['user_id'])['age'].std().max()
# Out:
# 0.0

# %%
df.groupby(['user_id'])['followers'].std().max()
# Out:
# 141.4213562373095

# %%
cat_id = df.groupby(['category_id']).agg({'user_id':pd.Series.nunique,
                                          'video_id':pd.Series.nunique,
                                          'views':['mean','sum','count'],
                                          'followers':['mean','sum'],
                                           'engagement_score': cv,
                                          })

cat_id.columns = ["_".join(x) for x in cat_id.columns]
cat_id = cat_id.add_suffix("_cat")
cat_id = cat_id.reset_index()

cat_id.describe()
# Out:
#        category_id  ...  engagement_score_cv_cat
# count    47.000000  ...                47.000000
# mean     24.000000  ...                 0.989477
# std      13.711309  ...                 0.085867
# min       1.000000  ...                 0.762331
# 25%      12.500000  ...                 0.952688
# 50%      24.000000  ...                 0.986967
# 75%      35.500000  ...                 1.040323
# max      47.000000  ...                 1.159309
#
# [8 rows x 9 columns]

# %%
cat_id.sample(4)
# Out:
#     category_id  ...  engagement_score_cv_cat
# 7             8  ...                 1.032865
# 26           27  ...                 0.954991
# 29           30  ...                 0.969962
# 42           43  ...                 1.159309
#
# [4 rows x 9 columns]

# %%
video_id = df.groupby(['video_id']).agg({'user_id':pd.Series.nunique,
                                         'views':['mean','sum','count'],
                                         'followers':['mean','sum'],
                                         'engagement_score': cv,
                                         })
video_id.columns = ["_".join(x) for x in video_id.columns]
video_id = video_id.add_suffix("_vid")
video_id = video_id.reset_index()


video_id.describe()
# Out:
#          video_id  ...  engagement_score_cv_vid
# count  175.000000  ...               175.000000
# mean    88.000000  ...                 0.998231
# std     50.662281  ...                 0.075486
# min      1.000000  ...                 0.744485
# 25%     44.500000  ...                 0.961095
# 50%     88.000000  ...                 0.996008
# 75%    131.500000  ...                 1.044045
# max    175.000000  ...                 1.198430
#
# [8 rows x 8 columns]

# %%
video_id.sample(3)
# Out:
#      video_id  user_id_nunique_vid  ...  followers_sum_vid  engagement_score_cv_vid
# 172       173                   86  ...              16340                 0.894297
# 97         98                  823  ...             222210                 1.045095
# 136       137                  779  ...             210330                 0.993374
#
# [3 rows x 8 columns]

# %%
usr_cat = df.groupby(['user_id','category_id']).agg({'video_id':pd.Series.nunique,
                                                     'views':['mean','sum','count',cv],
                                                     'followers':['mean','sum',cv],
                                                    # 'engagement_score': cv,
                                                     })
usr_cat.columns = ["_".join(x) for x in usr_cat.columns]
usr_cat = usr_cat.add_suffix("_usr_cat")
usr_cat = usr_cat.reset_index()


usr_cat.describe()
# Out:
#             user_id   category_id  ...  followers_sum_usr_cat  followers_cv_usr_cat
# count  49890.000000  49890.000000  ...           49890.000000          49890.000000
# mean   13860.321227     19.483664  ...             507.025656             72.786145
# std     8003.431271     11.855247  ...             278.288983             13.655772
# min        1.000000      1.000000  ...             160.000000             45.874229
# 25%     6931.250000      9.000000  ...             280.000000             65.944205
# 50%    13844.000000     18.000000  ...             460.000000             68.811344
# 75%    20792.750000     28.000000  ...             660.000000             80.279901
# max    27734.000000     47.000000  ...            2640.000000            103.217016
#
# [8 rows x 10 columns]

# %%
vid_cat = df.groupby(['video_id','category_id']).agg({'user_id':pd.Series.nunique,
                                                     'views':['mean','sum','count'],
                                                     'followers':['mean','sum',],
                                                    #  'engagement_score': cv,
                                                     })
vid_cat.columns = ["_".join(x) for x in vid_cat.columns]
vid_cat = vid_cat.add_suffix("_usr_cat")
vid_cat = vid_cat.reset_index()


vid_cat.describe()
# Out:
#          video_id  category_id  ...  followers_mean_usr_cat  followers_sum_usr_cat
# count  176.000000   176.000000  ...              176.000000             176.000000
# mean    87.505682    18.676136  ...              249.204545          143724.488636
# std     50.941198    12.955868  ...               43.113713           76840.120865
# min      1.000000     1.000000  ...              160.000000           12220.000000
# 25%     43.750000     6.750000  ...              230.000000           76417.500000
# 50%     87.500000    16.000000  ...              240.000000          145425.000000
# 75%    131.250000    29.250000  ...              270.000000          207250.000000
# max    175.000000    47.000000  ...              360.000000          352960.000000
#
# [8 rows x 8 columns]

# %%
all_cat = df.groupby(['user_id','video_id','category_id']).agg({
                                                        'views':['mean','sum','count'],
                                                     'followers':['mean','sum',],
                                                    #  'engagement_score': cv,
                                                     })
all_cat.columns = ["_".join(x) for x in all_cat.columns]
all_cat = all_cat.add_suffix("_usr_cat")
all_cat = all_cat.reset_index()


all_cat.describe()
# Out:
#              user_id  ...  followers_sum_usr_cat
# count  100318.000000  ...          100318.000000
# mean    13875.679350  ...             252.153253
# std      8005.079041  ...              45.324580
# min         1.000000  ...             160.000000
# 25%      6938.250000  ...             230.000000
# 50%     13889.000000  ...             240.000000
# 75%     20813.000000  ...             280.000000
# max     27734.000000  ...             360.000000
#
# [8 rows x 8 columns]

# %%
row_df = df.set_index('row_id')
row_df.head(3)
# Out:
#         user_id  category_id  video_id  ...  followers views engagement_score
# row_id                                  ...
# 1         19990           37       128  ...        180  1000             4.33
# 2          5304           32       132  ...        330   714             1.79
# 3          1840           12        24  ...        180   138             4.35
#
# [3 rows x 9 columns]

# %%
# row_min = df.groupby(['user_id'])['row_id'].min()
# row_max = df.groupby(['user_id'])['row_id'].max()
# user_min = row_df.loc[row_min.values, ['followers','views','user_id']]
# user_max = row_df.loc[row_max.values, ['followers','views','user_id']]
# user_max = user_max.set_index('user_id')
# user_min = user_min.set_index('user_id')
# user_growth = (user_max-user_min)/user_min
# user_growth.head(3)

# %%
row_min = df.groupby(['user_id'])[['views','followers','engagement_score']].min()
row_max = df.groupby(['user_id'])[['views','followers','engagement_score']].max()
user_growth = (row_max-row_min)/row_min
user_growth = user_growth.fillna(0).replace({np.inf:0}).add_suffix('_usr_rate').reset_index()
user_growth.head(3)
# Out:
#    user_id  views_usr_rate  followers_usr_rate  engagement_score_usr_rate
# 0        1       32.000000            0.636364                   0.270833
# 1        2        0.257649            0.173913                   0.377358
# 2        3        0.580786            0.142857                   0.058005

# %%
user_growth.describe()
# Out:
#             user_id  ...  engagement_score_usr_rate
# count  27734.000000  ...               27734.000000
# mean   13867.500000  ...                   0.546073
# std     8006.260519  ...                   4.893583
# min        1.000000  ...                   0.000000
# 25%     6934.250000  ...                   0.073894
# 50%    13867.500000  ...                   0.185751
# 75%    20800.750000  ...                   0.533333
# max    27734.000000  ...                 229.500000
#
# [8 rows x 4 columns]

# %%
row_min = df.groupby(['video_id'])[['views','followers','engagement_score']].min()
row_max = df.groupby(['video_id'])[['views','followers','engagement_score']].max()
vid_growth = (row_max-row_min)/row_min
vid_growth = vid_growth.fillna(0).replace({np.inf:0,-np.inf:0}).add_suffix('_vid_rate').reset_index()
vid_growth.describe()
# Out:
#          video_id  ...  engagement_score_vid_rate
# count  175.000000  ...                 175.000000
# mean    88.000000  ...                  14.766109
# std     50.662281  ...                  50.668556
# min      1.000000  ...                   0.000000
# 25%     44.500000  ...                   0.000000
# 50%     88.000000  ...                   1.553846
# 75%    131.500000  ...                  10.111111
# max    175.000000  ...                 249.000000
#
# [8 rows x 4 columns]

# %%
# row_min = df.groupby(['category_id'])[['views','followers','engagement_score']].min()
# row_max = df.groupby(['category_id'])[['views','followers','engagement_score']].max()
# cat_growth = (row_max-row_min)/row_min
# cat_growth = cat_growth.fillna(0).replace({np.inf:0,-np.inf:0}).add_suffix('_cat_rate').reset_index()
# cat_growth.describe()

# %%
# raw_train.head(3)

# %%
featured_df = df.copy()
featured_df = featured_df.merge(user_profile,how='left',on=['user_id'])
featured_df = featured_df.merge(cat_id,how='left',on=['category_id'])
featured_df = featured_df.merge(video_id,how='left',on=['video_id'])
featured_df = featured_df.merge(usr_cat,how='left',on=['user_id','category_id'])
featured_df = featured_df.merge(vid_cat,how='left',on=['video_id','category_id'])
featured_df = featured_df.merge(all_cat,how='left',on=['user_id','category_id','video_id'])


featured_df = featured_df.merge(user_growth,how='left',on=['user_id'])
# featured_df = featured_df.merge(cat_growth,how='left',on=['category_id'])
featured_df = featured_df.merge(vid_growth,how='left',on=['video_id'])


featured_df.head(3)
# Out:
#    row_id  user_id  ...  followers_vid_rate  engagement_score_vid_rate
# 0       1    19990  ...                 0.0                        0.0
# 1       2     5304  ...                 0.0                        0.0
# 2       3     1840  ...                 0.0                        0.0
#
# [3 rows x 60 columns]

# %%
featured_df['profession'].unique()
# Out:
# array(['Student', 'Working Professional', 'Other'], dtype=object)

# %%
featured_df['male'] = (featured_df['gender'] == 'Male').astype(int)
featured_df['student'] = (featured_df['profession'] == 'Student').astype(int)
featured_df['working'] = (featured_df['profession'] == 'Working Professional').astype(int)
featured_df.sample(3)
# Out:
#        row_id  user_id  category_id  ...  male  student working
# 34748   34749    24908           12  ...     1        1       0
# 33842   33843    16625           15  ...     1        0       0
# 45433   45434    22217            5  ...     0        0       1
#
# [3 rows x 63 columns]

# %%
train = featured_df[featured_df['engagement_score'].notna()].copy()
test = featured_df[featured_df['engagement_score'].isna()].copy()
train.shape[0] == raw_train.shape[0], test.shape[0] == raw_test.shape[0]
# Out:
# (True, True)

# %%
train.sample(3)
# Out:
#        row_id  user_id  category_id  ...  male  student working
# 65062   65063    11143           25  ...     0        1       0
# 34821   34822     4421            3  ...     0        1       0
# 24974   24975     3061            7  ...     1        0       1
#
# [3 rows x 63 columns]

# %%
drop_col = [
            'row_id',
            'user_id','category_id','video_id',
            'gender','profession',
            #'usr_rank',
            #'cat_rank','video_rank',
]

# %%
sub_train = train.drop(drop_col,axis=1)
sub_train.head(3)
# Out:
#    age  followers  views  ...  male  student  working
# 0   24        180   1000  ...     1        1        0
# 1   14        330    714  ...     0        1        0
# 2   19        180    138  ...     1        1        0
#
# [3 rows x 57 columns]

# %%
# corr = sub_train.corr().round(2)
# plt.figure(figsize=(15,8))
# sns.heatmap(corr,annot=False)

# %%
x_train = sub_train.drop(['engagement_score'],axis=1)
y_train = sub_train['engagement_score']

scaler = StandardScaler()
train_scaled = scaler.fit_transform(x_train)
x_train = pd.DataFrame(train_scaled,index=x_train.index,columns=x_train.columns)
x_train.head(3)
# Out:
#         age  followers     views  ...      male   student  working
# 0 -0.094759  -1.572002  1.850629  ...  0.838051  0.999115 -0.49789
# 1 -1.211393   1.682203  0.785722  ... -1.193244  0.999115 -0.49789
# 2 -0.653076  -1.572002 -1.358987  ...  0.838051  0.999115 -0.49789
#
# [3 rows x 56 columns]

# %%
r2_scorer = make_scorer(r2_score)

# %%
def cross_validation(x_train,y_train,model,model_name,cv=5,scoring=r2_scorer):
    scores = cross_val_score(model, x_train, y_train, cv=5,scoring=scoring)
    print(f"{model_name}: mean r2_score {scores.mean():.2f} with a standard deviation of {scores.std():.2f}")
    return

# %%
dummy_model = DummyRegressor()
cross_validation(x_train,y_train,dummy_model,'Dummy Model')
# Out:
# Dummy Model: mean r2_score -0.00 with a standard deviation of 0.00

# %%
linear_model = LinearRegression()
cross_validation(x_train,y_train,linear_model,'Linear Model')
# Out:
# Linear Model: mean r2_score 0.68 with a standard deviation of 0.00

# %%
# svm_model = SVR(kernel='poly',degree=1)
# cross_validation(x_train,y_train,svm_model,'SVM Model')

# %%
knn_model = KNeighborsRegressor()
cross_validation(x_train,y_train,knn_model,'KNN Model')
# Out:
# KNN Model: mean r2_score 0.59 with a standard deviation of 0.00

# %%
rf_model =  RandomForestRegressor(max_depth=9, random_state=100)
cross_validation(x_train,y_train,rf_model,'Random Forest Model')
# Out:
# Random Forest Model: mean r2_score 0.71 with a standard deviation of 0.00

# %%
ada_boost_model =  AdaBoostRegressor(random_state=100)
cross_validation(x_train,y_train,ada_boost_model,'AdaBoot')
# Out:
# AdaBoot: mean r2_score 0.63 with a standard deviation of 0.00

# %%
gbr_model =  GradientBoostingRegressor(max_depth=5, random_state=100,subsample=0.9,learning_rate=0.05)
cross_validation(x_train,y_train,gbr_model,'Gradient boosting')
# Out:
# Gradient boosting: mean r2_score 0.71 with a standard deviation of 0.00

# %%
gbr_model =  HistGradientBoostingRegressor(max_depth=7, random_state=100,learning_rate=0.05)
cross_validation(x_train,y_train,gbr_model,'Gradient boosting')
# Out:
# Gradient boosting: mean r2_score 0.72 with a standard deviation of 0.00

# %%
xgb_model =  xgb.XGBRegressor(n_estimators=100,max_depth=11, random_state=100,learning_rate=0.05,
                              subsample=1,colsample_bytree =1,objective='reg:squarederror')
cross_validation(x_train,y_train,xgb_model,'XGB')
# Out:
# XGB: mean r2_score 0.72 with a standard deviation of 0.00

# %%
hyper_params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': ['l1','l2'],
    'learning_rate': 0.05,
    'feature_fraction': 0.95,
    'bagging_fraction': 0.95,
    'bagging_freq': 10,
    'verbose': 0,
    "max_depth": 15,
    "num_leaves": 128,  
    "max_bin": 512,
    "n_estimators": 200,
    "random_state":345
}
lgb_model = lgb.LGBMRegressor(**hyper_params)
cross_validation(x_train,y_train,lgb_model,'LGB')
# Out:
# LGB: mean r2_score 0.73 with a standard deviation of 0.01

# %%
model = lgb_model.fit(x_train,y_train)

# %%
x_test = test[x_train.columns].copy()
scaled_test = scaler.transform(x_test)
x_test = pd.DataFrame(scaled_test,index=x_test.index,columns=x_test.columns)
x_test.head(3)
# Out:
#             age  followers     views  ...      male   student   working
# 89197 -1.211393  -1.572002 -1.358987  ...  0.838051  0.999115 -0.497890
# 89198 -1.211393  -0.487267  1.254877  ...  0.838051  0.999115 -0.497890
# 89199  2.138509   0.597468  0.465505  ... -1.193244 -1.000886  2.008476
#
# [3 rows x 56 columns]

# %%
x_test['engagement_score'] = model.predict(x_test)
x_test['engagement_score'].head(3)
# Out:
# 89197    4.208551
# 89198    4.081771
# 89199    2.324123
# Name: engagement_score, dtype: float64

# %%
test['engagement_score'] = x_test['engagement_score']
test[['row_id','engagement_score']].to_csv("submission_6_lgb.csv",index=False)

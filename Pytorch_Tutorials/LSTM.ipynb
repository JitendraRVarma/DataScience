# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %%
# make the sequence data
N = 2500
series = series = np.sin((0.01*np.arange(N))**2)

# plot it
plt.figure(figsize=(18,8))
plt.plot(series)

# %%
### build the dataset
# let's see if we can use T past values to predict the next value
T = 10
X = []
Y = []
for t in range(len(series) - T):
    x = series[t:t+T]
    X.append(x)
    y = series[t+T]
    Y.append(y)

# reshaping as RNN expects 3D array input
X = np.array(X).reshape(-1, T, 1)

# reshaping Y as torch expects multioutput
Y = np.array(Y).reshape(-1, 1)

N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (2490, 10, 1) Y.shape (2490, 1)

# %%
# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
### Define RNN
class LSTM(nn.Module):
    def __init__(self, n_inputs, n_hidden, n_rnnlayers, n_outputs):
        super(LSTM, self).__init__()
        self.D = n_inputs
        self.M = n_hidden
        self.K = n_outputs
        self.L = n_rnnlayers

        # note: batch_first=True
        # applies the convention that our data will be of shape:
        # (num_samples, sequence_length, num_features)
        # rather than:
        # (sequence_length, num_samples, num_features)
        
        self.rnn = nn.LSTM(input_size=self.D,
                           hidden_size=self.M,
                           num_layers=self.L,
                           batch_first=True)
        
        self.fc =nn.Linear(self.M, self.K)

    def forward(self, X):
        # initial hidden states
        h0 = torch.zeros(self.L, X.size(0), self.M).to(device)
        c0 = torch.zeros(self.L, X.size(0), self.M).to(device)

        # get RNN unit output
        # out is of size (N, T, M)
        # 2nd return value is hidden states at each hidden layer
        # we don't need those now
        out, _ = self.rnn(X, (h0, c0))

        # we only want h(T) at the final time step
        out = self.fc(out[:, -1, :])
        return out

# %%
# Instantiate the model
model = LSTM(n_inputs=1, n_hidden=10, n_rnnlayers=1, n_outputs=1)
model.to(device)
# Out:
# LSTM(
#   (rnn): LSTM(1, 10, batch_first=True)
#   (fc): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
# Loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
# Make inputs and targets
X_train = torch.from_numpy(X[:-N//2].astype(np.float32))
y_train = torch.from_numpy(Y[:-N//2].astype(np.float32))
X_test = torch.from_numpy(X[-N//2:].astype(np.float32))
y_test = torch.from_numpy(Y[-N//2:].astype(np.float32))

# %%
# move data to GPU
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# %%
# Training full gradient descent
def full_gd(model,criterion, optimizer, X_train, y_train, 
            X_test, y_test,epochs=1000):

    # losses to store
    train_losses = np.zeros(epochs)
    test_losses = np.zeros(epochs)

    for it in range(epochs):
        # zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
            
        # Backward and optimize
        loss.backward()
        optimizer.step()

        # Save losses
        train_losses[it] = loss.item()

        # Test loss
        test_outputs = model(X_test)
        test_loss = criterion(test_outputs, y_test)
        test_losses[it] = test_loss.item()
            
        if (it + 1) % 5 == 0:
            print(f'Epoch {it+1}/{epochs}, Train Loss: {loss.item():.4f}, Test Loss: {test_loss.item():.4f}')

    return train_losses, test_losses

# %%
train_losses, test_losses = full_gd(model,criterion,optimizer,
                                    X_train, y_train, 
                                    X_test, y_test)
# Out:
# Epoch 5/1000, Train Loss: 0.4488, Test Loss: 0.4718
# Epoch 10/1000, Train Loss: 0.3166, Test Loss: 0.4276
# Epoch 15/1000, Train Loss: 0.1929, Test Loss: 0.4373
# Epoch 20/1000, Train Loss: 0.1257, Test Loss: 0.4772
# Epoch 25/1000, Train Loss: 0.0874, Test Loss: 0.3689
# Epoch 30/1000, Train Loss: 0.0382, Test Loss: 0.2112
# Epoch 35/1000, Train Loss: 0.0237, Test Loss: 0.1703
# Epoch 40/1000, Train Loss: 0.0127, Test Loss: 0.2161
# Epoch 45/1000, Train Loss: 0.0138, Test Loss: 0.2132
# Epoch 50/1000, Train Loss: 0.0068, Test Loss: 0.1271
# Epoch 55/1000, Train Loss: 0.0069, Test Loss: 0.1118
# Epoch 60/1000, Train Loss: 0.0059, Test Loss: 0.1243
# Epoch 65/1000, Train Loss: 0.0049, Test Loss: 0.1110
# Epoch 70/1000, Train Loss: 0.0042, Test Loss: 0.0973
# Epoch 75/1000, Train Loss: 0.0036, Test Loss: 0.1076
# Epoch 80/1000, Train Loss: 0.0033, Test Loss: 0.1009
# Epoch 85/1000, Train Loss: 0.0029, Test Loss: 0.0870
# Epoch 90/1000, Train Loss: 0.0027, Test Loss: 0.0856
# Epoch 95/1000, Train Loss: 0.0025, Test Loss: 0.0834
# Epoch 100/1000, Train Loss: 0.0023, Test Loss: 0.0790
# Epoch 105/1000, Train Loss: 0.0021, Test Loss: 0.0816
# Epoch 110/1000, Train Loss: 0.0020, Test Loss: 0.0797
# Epoch 115/1000, Train Loss: 0.0019, Test Loss: 0.0764
# Epoch 120/1000, Train Loss: 0.0018, Test Loss: 0.0759
# Epoch 125/1000, Train Loss: 0.0017, Test Loss: 0.0741
# Epoch 130/1000, Train Loss: 0.0016, Test Loss: 0.0736
# Epoch 135/1000, Train Loss: 0.0015, Test Loss: 0.0733
# Epoch 140/1000, Train Loss: 0.0015, Test Loss: 0.0718
# Epoch 145/1000, Train Loss: 0.0014, Test Loss: 0.0711
# Epoch 150/1000, Train Loss: 0.0013, Test Loss: 0.0702
# Epoch 155/1000, Train Loss: 0.0013, Test Loss: 0.0695
# Epoch 160/1000, Train Loss: 0.0012, Test Loss: 0.0688
# Epoch 165/1000, Train Loss: 0.0011, Test Loss: 0.0678
# Epoch 170/1000, Train Loss: 0.0011, Test Loss: 0.0671
# Epoch 175/1000, Train Loss: 0.0010, Test Loss: 0.0663
# Epoch 180/1000, Train Loss: 0.0010, Test Loss: 0.0656
# Epoch 185/1000, Train Loss: 0.0009, Test Loss: 0.0648
# Epoch 190/1000, Train Loss: 0.0009, Test Loss: 0.0639
# Epoch 195/1000, Train Loss: 0.0008, Test Loss: 0.0631
# Epoch 200/1000, Train Loss: 0.0008, Test Loss: 0.0623
# Epoch 205/1000, Train Loss: 0.0008, Test Loss: 0.0615
# Epoch 210/1000, Train Loss: 0.0007, Test Loss: 0.0607
# Epoch 215/1000, Train Loss: 0.0007, Test Loss: 0.0599
# Epoch 220/1000, Train Loss: 0.0007, Test Loss: 0.0591
# Epoch 225/1000, Train Loss: 0.0006, Test Loss: 0.0584
# Epoch 230/1000, Train Loss: 0.0006, Test Loss: 0.0576
# Epoch 235/1000, Train Loss: 0.0006, Test Loss: 0.0569
# Epoch 240/1000, Train Loss: 0.0006, Test Loss: 0.0562
# Epoch 245/1000, Train Loss: 0.0005, Test Loss: 0.0554
# Epoch 250/1000, Train Loss: 0.0005, Test Loss: 0.0547
# Epoch 255/1000, Train Loss: 0.0005, Test Loss: 0.0541
# Epoch 260/1000, Train Loss: 0.0005, Test Loss: 0.0534
# Epoch 265/1000, Train Loss: 0.0005, Test Loss: 0.0528
# Epoch 270/1000, Train Loss: 0.0004, Test Loss: 0.0521
# Epoch 275/1000, Train Loss: 0.0004, Test Loss: 0.0515
# Epoch 280/1000, Train Loss: 0.0004, Test Loss: 0.0508
# Epoch 285/1000, Train Loss: 0.0004, Test Loss: 0.0502
# Epoch 290/1000, Train Loss: 0.0004, Test Loss: 0.0496
# Epoch 295/1000, Train Loss: 0.0004, Test Loss: 0.0490
# Epoch 300/1000, Train Loss: 0.0004, Test Loss: 0.0484
# Epoch 305/1000, Train Loss: 0.0003, Test Loss: 0.0478
# Epoch 310/1000, Train Loss: 0.0003, Test Loss: 0.0472
# Epoch 315/1000, Train Loss: 0.0003, Test Loss: 0.0466
# Epoch 320/1000, Train Loss: 0.0003, Test Loss: 0.0460
# Epoch 325/1000, Train Loss: 0.0003, Test Loss: 0.0453
# Epoch 330/1000, Train Loss: 0.0003, Test Loss: 0.0447
# Epoch 335/1000, Train Loss: 0.0003, Test Loss: 0.0441
# Epoch 340/1000, Train Loss: 0.0003, Test Loss: 0.0435
# Epoch 345/1000, Train Loss: 0.0003, Test Loss: 0.0429
# Epoch 350/1000, Train Loss: 0.0002, Test Loss: 0.0423
# Epoch 355/1000, Train Loss: 0.0002, Test Loss: 0.0417
# Epoch 360/1000, Train Loss: 0.0002, Test Loss: 0.0411
# Epoch 365/1000, Train Loss: 0.0002, Test Loss: 0.0405
# Epoch 370/1000, Train Loss: 0.0002, Test Loss: 0.0399
# Epoch 375/1000, Train Loss: 0.0002, Test Loss: 0.0393
# Epoch 380/1000, Train Loss: 0.0002, Test Loss: 0.0387
# Epoch 385/1000, Train Loss: 0.0002, Test Loss: 0.0381
# Epoch 390/1000, Train Loss: 0.0002, Test Loss: 0.0375
# Epoch 395/1000, Train Loss: 0.0002, Test Loss: 0.0369
# Epoch 400/1000, Train Loss: 0.0002, Test Loss: 0.0363
# Epoch 405/1000, Train Loss: 0.0001, Test Loss: 0.0357
# Epoch 410/1000, Train Loss: 0.0001, Test Loss: 0.0351
# Epoch 415/1000, Train Loss: 0.0001, Test Loss: 0.0346
# Epoch 420/1000, Train Loss: 0.0001, Test Loss: 0.0340
# Epoch 425/1000, Train Loss: 0.0001, Test Loss: 0.0335
# Epoch 430/1000, Train Loss: 0.0001, Test Loss: 0.0329
# Epoch 435/1000, Train Loss: 0.0001, Test Loss: 0.0324
# Epoch 440/1000, Train Loss: 0.0001, Test Loss: 0.0319
# Epoch 445/1000, Train Loss: 0.0001, Test Loss: 0.0314
# Epoch 450/1000, Train Loss: 0.0001, Test Loss: 0.0309
# Epoch 455/1000, Train Loss: 0.0001, Test Loss: 0.0305
# Epoch 460/1000, Train Loss: 0.0001, Test Loss: 0.0301
# Epoch 465/1000, Train Loss: 0.0001, Test Loss: 0.0297
# Epoch 470/1000, Train Loss: 0.0001, Test Loss: 0.0293
# Epoch 475/1000, Train Loss: 0.0001, Test Loss: 0.0290
# Epoch 480/1000, Train Loss: 0.0001, Test Loss: 0.0287
# Epoch 485/1000, Train Loss: 0.0001, Test Loss: 0.0284
# Epoch 490/1000, Train Loss: 0.0001, Test Loss: 0.0282
# Epoch 495/1000, Train Loss: 0.0001, Test Loss: 0.0279
# Epoch 500/1000, Train Loss: 0.0001, Test Loss: 0.0277
# Epoch 505/1000, Train Loss: 0.0000, Test Loss: 0.0275
# Epoch 510/1000, Train Loss: 0.0000, Test Loss: 0.0274
# Epoch 515/1000, Train Loss: 0.0000, Test Loss: 0.0272
# Epoch 520/1000, Train Loss: 0.0000, Test Loss: 0.0271
# Epoch 525/1000, Train Loss: 0.0000, Test Loss: 0.0269
# Epoch 530/1000, Train Loss: 0.0000, Test Loss: 0.0268
# Epoch 535/1000, Train Loss: 0.0000, Test Loss: 0.0266
# Epoch 540/1000, Train Loss: 0.0000, Test Loss: 0.0265
# Epoch 545/1000, Train Loss: 0.0000, Test Loss: 0.0264
# Epoch 550/1000, Train Loss: 0.0000, Test Loss: 0.0263
# Epoch 555/1000, Train Loss: 0.0000, Test Loss: 0.0261
# Epoch 560/1000, Train Loss: 0.0000, Test Loss: 0.0260
# Epoch 565/1000, Train Loss: 0.0000, Test Loss: 0.0259
# Epoch 570/1000, Train Loss: 0.0000, Test Loss: 0.0258
# Epoch 575/1000, Train Loss: 0.0000, Test Loss: 0.0257
# Epoch 580/1000, Train Loss: 0.0000, Test Loss: 0.0257
# Epoch 585/1000, Train Loss: 0.0000, Test Loss: 0.0256
# Epoch 590/1000, Train Loss: 0.0000, Test Loss: 0.0255
# Epoch 595/1000, Train Loss: 0.0000, Test Loss: 0.0254
# Epoch 600/1000, Train Loss: 0.0000, Test Loss: 0.0253
# Epoch 605/1000, Train Loss: 0.0000, Test Loss: 0.0253
# Epoch 610/1000, Train Loss: 0.0000, Test Loss: 0.0252
# Epoch 615/1000, Train Loss: 0.0000, Test Loss: 0.0251
# Epoch 620/1000, Train Loss: 0.0000, Test Loss: 0.0251
# Epoch 625/1000, Train Loss: 0.0000, Test Loss: 0.0250
# Epoch 630/1000, Train Loss: 0.0000, Test Loss: 0.0250
# Epoch 635/1000, Train Loss: 0.0000, Test Loss: 0.0249
# Epoch 640/1000, Train Loss: 0.0000, Test Loss: 0.0249
# Epoch 645/1000, Train Loss: 0.0000, Test Loss: 0.0248
# Epoch 650/1000, Train Loss: 0.0000, Test Loss: 0.0248
# Epoch 655/1000, Train Loss: 0.0000, Test Loss: 0.0247
# Epoch 660/1000, Train Loss: 0.0000, Test Loss: 0.0247
# Epoch 665/1000, Train Loss: 0.0000, Test Loss: 0.0246
# Epoch 670/1000, Train Loss: 0.0000, Test Loss: 0.0246
# Epoch 675/1000, Train Loss: 0.0000, Test Loss: 0.0245
# Epoch 680/1000, Train Loss: 0.0000, Test Loss: 0.0245
# Epoch 685/1000, Train Loss: 0.0000, Test Loss: 0.0244
# Epoch 690/1000, Train Loss: 0.0000, Test Loss: 0.0244
# Epoch 695/1000, Train Loss: 0.0000, Test Loss: 0.0243
# Epoch 700/1000, Train Loss: 0.0000, Test Loss: 0.0243
# Epoch 705/1000, Train Loss: 0.0000, Test Loss: 0.0243
# Epoch 710/1000, Train Loss: 0.0000, Test Loss: 0.0242
# Epoch 715/1000, Train Loss: 0.0000, Test Loss: 0.0241
# Epoch 720/1000, Train Loss: 0.0002, Test Loss: 0.0245
# Epoch 725/1000, Train Loss: 0.0002, Test Loss: 0.0241
# Epoch 730/1000, Train Loss: 0.0000, Test Loss: 0.0239
# Epoch 735/1000, Train Loss: 0.0001, Test Loss: 0.0237
# Epoch 740/1000, Train Loss: 0.0000, Test Loss: 0.0239
# Epoch 745/1000, Train Loss: 0.0001, Test Loss: 0.0239
# Epoch 750/1000, Train Loss: 0.0000, Test Loss: 0.0240
# Epoch 755/1000, Train Loss: 0.0000, Test Loss: 0.0242
# Epoch 760/1000, Train Loss: 0.0000, Test Loss: 0.0241
# Epoch 765/1000, Train Loss: 0.0000, Test Loss: 0.0240
# Epoch 770/1000, Train Loss: 0.0000, Test Loss: 0.0240
# Epoch 775/1000, Train Loss: 0.0000, Test Loss: 0.0239
# Epoch 780/1000, Train Loss: 0.0000, Test Loss: 0.0239
# Epoch 785/1000, Train Loss: 0.0000, Test Loss: 0.0239
# Epoch 790/1000, Train Loss: 0.0000, Test Loss: 0.0239
# Epoch 795/1000, Train Loss: 0.0000, Test Loss: 0.0239
# Epoch 800/1000, Train Loss: 0.0000, Test Loss: 0.0239
# Epoch 805/1000, Train Loss: 0.0000, Test Loss: 0.0238
# Epoch 810/1000, Train Loss: 0.0000, Test Loss: 0.0238
# Epoch 815/1000, Train Loss: 0.0000, Test Loss: 0.0237
# Epoch 820/1000, Train Loss: 0.0000, Test Loss: 0.0237
# Epoch 825/1000, Train Loss: 0.0000, Test Loss: 0.0236
# Epoch 830/1000, Train Loss: 0.0000, Test Loss: 0.0236
# Epoch 835/1000, Train Loss: 0.0000, Test Loss: 0.0235
# Epoch 840/1000, Train Loss: 0.0000, Test Loss: 0.0235
# Epoch 845/1000, Train Loss: 0.0000, Test Loss: 0.0235
# Epoch 850/1000, Train Loss: 0.0000, Test Loss: 0.0234
# Epoch 855/1000, Train Loss: 0.0000, Test Loss: 0.0234
# Epoch 860/1000, Train Loss: 0.0000, Test Loss: 0.0233
# Epoch 865/1000, Train Loss: 0.0000, Test Loss: 0.0233
# Epoch 870/1000, Train Loss: 0.0000, Test Loss: 0.0233
# Epoch 875/1000, Train Loss: 0.0000, Test Loss: 0.0232
# Epoch 880/1000, Train Loss: 0.0000, Test Loss: 0.0232
# Epoch 885/1000, Train Loss: 0.0000, Test Loss: 0.0231
# Epoch 890/1000, Train Loss: 0.0000, Test Loss: 0.0231
# Epoch 895/1000, Train Loss: 0.0000, Test Loss: 0.0231
# Epoch 900/1000, Train Loss: 0.0000, Test Loss: 0.0230
# Epoch 905/1000, Train Loss: 0.0000, Test Loss: 0.0230
# Epoch 910/1000, Train Loss: 0.0000, Test Loss: 0.0230
# Epoch 915/1000, Train Loss: 0.0000, Test Loss: 0.0229
# Epoch 920/1000, Train Loss: 0.0000, Test Loss: 0.0229
# Epoch 925/1000, Train Loss: 0.0000, Test Loss: 0.0228
# Epoch 930/1000, Train Loss: 0.0000, Test Loss: 0.0228
# Epoch 935/1000, Train Loss: 0.0000, Test Loss: 0.0228
# Epoch 940/1000, Train Loss: 0.0000, Test Loss: 0.0227
# Epoch 945/1000, Train Loss: 0.0000, Test Loss: 0.0227
# Epoch 950/1000, Train Loss: 0.0000, Test Loss: 0.0227
# Epoch 955/1000, Train Loss: 0.0000, Test Loss: 0.0226
# Epoch 960/1000, Train Loss: 0.0000, Test Loss: 0.0226
# Epoch 965/1000, Train Loss: 0.0000, Test Loss: 0.0226
# Epoch 970/1000, Train Loss: 0.0000, Test Loss: 0.0225
# Epoch 975/1000, Train Loss: 0.0000, Test Loss: 0.0225
# Epoch 980/1000, Train Loss: 0.0000, Test Loss: 0.0225
# Epoch 985/1000, Train Loss: 0.0000, Test Loss: 0.0224
# Epoch 990/1000, Train Loss: 0.0000, Test Loss: 0.0224
# Epoch 995/1000, Train Loss: 0.0000, Test Loss: 0.0224
# Epoch 1000/1000, Train Loss: 0.0000, Test Loss: 0.0223

# %%
# Plot the train loss and test loss per iteration
plt.figure(figsize=(15,8))
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.legend()
plt.show()

# %%
# Forecast future values (use only self-predictions for making future predictions)

validation_target = Y[-N//2:]
validation_predictions = []

# last train input
# last_x = torch.from_numpy(X[-N//2]) # 1-D array of length T
# last_x = torch.from_numpy(X[-N//2].astype(np.float32))
last_x = X_test[0].view(T)

while len(validation_predictions) < len(validation_target):
  input_ = last_x.reshape(1, T, 1)
  p = model(input_)
  # [0,0] # 1x1 array -> scalar
  
  # update the predictions list
  validation_predictions.append(p[0,0].item())
  
  # make the new input
  last_x = torch.cat((last_x[1:], p[0]))

# %%
plt.figure(figsize=(15,8))
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(42)
sns.set()

# %%
# make the time series data by adding noise to sine wave
size = 500
series = np.sin(0.1*np.arange(size)) + np.random.randn(size)*0.1

# visulize the series
plt.figure(figsize=(15,5))
plt.plot(series)

# %%
# create sequence dataset where we will look T past values to predict next value
T = 10
X = []
Y = []

for t in range(len(series)-T):
    x = series[t:t+T]
    X.append(x)
    y = series[t+T]
    Y.append(y)
    
X = np.array(X)
Y = np.array(Y)

# %%
# print shape of X and Y
print("X shape {} and Y shape {}".format(X.shape,Y.shape))
# Out:
# X shape (490, 10) and Y shape (490,)

# %%
# Input to LSTM Layer
    # N = number of samples
    # T = sequence length
    # D = number of input features
    # M = number of hidden units
    # K = number of output units
# Input shape : N X T X D

# %%
X = np.array(X).reshape(-1, T, 1)
# print shape of X and Y
print("X shape {} and Y shape {}".format(X.shape,Y.shape))
# Out:
# X shape (490, 10, 1) and Y shape (490,)

# %%
# Train & Test Split
test_size = 0.50
test_len = int(190*test_size)
boundary = X.shape[0]-test_len

# Train input and output
X_train = X[:boundary]
y_train = Y[:boundary]

# Test input and output
X_test = X[boundary:]
y_test = Y[boundary:]

# %%
# print Train and Test Shape
print("X Train shape {} and Y Train shape {}".format(X_train.shape,y_train.shape))
print("X Test shape {} and Y Test shape {}".format(X_test.shape,y_test.shape))
# Out:
# X Train shape (395, 10, 1) and Y Train shape (395,)
# X Test shape (95, 10, 1) and Y Test shape (95,)

# %%
# LSTM Model for forecasting
i = Input(shape=(X_train.shape[1:]))
x = LSTM(5,activation='tanh')(i)   #LSTM with five hidden layer
x = Dense(1)(x)              # one output
model = Model(i,x)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 10, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 5)                 140
# _________________________________________________________________
# dense (Dense)                (None, 1)                 6
# =================================================================
# Total params: 146
# Trainable params: 146
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model compile
model.compile(optimizer='adam',loss='mse')

# train the model
hist = model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=50)
# Out:
# Train on 395 samples, validate on 95 samples
# Epoch 1/50
# 395/395 [==============================] - 3s 9ms/sample - loss: 0.2950 - val_loss: 0.3025
# Epoch 2/50
# 395/395 [==============================] - 0s 389us/sample - loss: 0.2347 - val_loss: 0.2432
# Epoch 3/50
# 395/395 [==============================] - 0s 333us/sample - loss: 0.1888 - val_loss: 0.1949
# Epoch 4/50
# 395/395 [==============================] - 0s 333us/sample - loss: 0.1549 - val_loss: 0.1571
# Epoch 5/50
# 395/395 [==============================] - 0s 389us/sample - loss: 0.1314 - val_loss: 0.1291
# Epoch 6/50
# 395/395 [==============================] - 0s 373us/sample - loss: 0.1145 - val_loss: 0.1122
# Epoch 7/50
# 395/395 [==============================] - 0s 350us/sample - loss: 0.1040 - val_loss: 0.1003
# Epoch 8/50
# 395/395 [==============================] - 0s 411us/sample - loss: 0.0970 - val_loss: 0.0912
# Epoch 9/50
# 395/395 [==============================] - 0s 349us/sample - loss: 0.0913 - val_loss: 0.0862
# Epoch 10/50
# 395/395 [==============================] - 0s 413us/sample - loss: 0.0869 - val_loss: 0.0818
# Epoch 11/50
# 395/395 [==============================] - 0s 350us/sample - loss: 0.0827 - val_loss: 0.0785
# Epoch 12/50
# 395/395 [==============================] - 0s 335us/sample - loss: 0.0793 - val_loss: 0.0761
# Epoch 13/50
# 395/395 [==============================] - 0s 389us/sample - loss: 0.0757 - val_loss: 0.0727
# Epoch 14/50
# 395/395 [==============================] - 0s 333us/sample - loss: 0.0725 - val_loss: 0.0694
# Epoch 15/50
# 395/395 [==============================] - 0s 372us/sample - loss: 0.0694 - val_loss: 0.0665
# Epoch 16/50
# 395/395 [==============================] - 0s 429us/sample - loss: 0.0665 - val_loss: 0.0639
# Epoch 17/50
# 395/395 [==============================] - 0s 391us/sample - loss: 0.0637 - val_loss: 0.0613
# Epoch 18/50
# 395/395 [==============================] - 0s 412us/sample - loss: 0.0609 - val_loss: 0.0596
# Epoch 19/50
# 395/395 [==============================] - 0s 333us/sample - loss: 0.0584 - val_loss: 0.0573
# Epoch 20/50
# 395/395 [==============================] - 0s 373us/sample - loss: 0.0558 - val_loss: 0.0545
# Epoch 21/50
# 395/395 [==============================] - 0s 390us/sample - loss: 0.0534 - val_loss: 0.0521
# Epoch 22/50
# 395/395 [==============================] - 0s 333us/sample - loss: 0.0510 - val_loss: 0.0495
# Epoch 23/50
# 395/395 [==============================] - 0s 372us/sample - loss: 0.0487 - val_loss: 0.0475
# Epoch 24/50
# 395/395 [==============================] - 0s 350us/sample - loss: 0.0464 - val_loss: 0.0456
# Epoch 25/50
# 395/395 [==============================] - 0s 373us/sample - loss: 0.0442 - val_loss: 0.0438
# Epoch 26/50
# 395/395 [==============================] - 0s 429us/sample - loss: 0.0421 - val_loss: 0.0414
# Epoch 27/50
# 395/395 [==============================] - 0s 389us/sample - loss: 0.0401 - val_loss: 0.0396
# Epoch 28/50
# 395/395 [==============================] - 0s 373us/sample - loss: 0.0383 - val_loss: 0.0384
# Epoch 29/50
# 395/395 [==============================] - 0s 373us/sample - loss: 0.0364 - val_loss: 0.0359
# Epoch 30/50
# 395/395 [==============================] - 0s 389us/sample - loss: 0.0346 - val_loss: 0.0345
# Epoch 31/50
# 395/395 [==============================] - 0s 388us/sample - loss: 0.0330 - val_loss: 0.0335
# Epoch 32/50
# 395/395 [==============================] - 0s 373us/sample - loss: 0.0313 - val_loss: 0.0316
# Epoch 33/50
# 395/395 [==============================] - 0s 351us/sample - loss: 0.0299 - val_loss: 0.0301
# Epoch 34/50
# 395/395 [==============================] - 0s 373us/sample - loss: 0.0286 - val_loss: 0.0288
# Epoch 35/50
# 395/395 [==============================] - 0s 389us/sample - loss: 0.0273 - val_loss: 0.0281
# Epoch 36/50
# 395/395 [==============================] - 0s 412us/sample - loss: 0.0263 - val_loss: 0.0274
# Epoch 37/50
# 395/395 [==============================] - 0s 429us/sample - loss: 0.0253 - val_loss: 0.0262
# Epoch 38/50
# 395/395 [==============================] - 0s 429us/sample - loss: 0.0244 - val_loss: 0.0254
# Epoch 39/50
# 395/395 [==============================] - 0s 412us/sample - loss: 0.0236 - val_loss: 0.0249
# Epoch 40/50
# 395/395 [==============================] - 0s 389us/sample - loss: 0.0229 - val_loss: 0.0243
# Epoch 41/50
# 395/395 [==============================] - 0s 412us/sample - loss: 0.0223 - val_loss: 0.0237
# Epoch 42/50
# 395/395 [==============================] - 0s 351us/sample - loss: 0.0217 - val_loss: 0.0231
# Epoch 43/50
# 395/395 [==============================] - 0s 372us/sample - loss: 0.0214 - val_loss: 0.0226
# Epoch 44/50
# 395/395 [==============================] - 0s 429us/sample - loss: 0.0210 - val_loss: 0.0225
# Epoch 45/50
# 395/395 [==============================] - 0s 428us/sample - loss: 0.0206 - val_loss: 0.0222
# Epoch 46/50
# 395/395 [==============================] - 0s 412us/sample - loss: 0.0203 - val_loss: 0.0218
# Epoch 47/50
# 395/395 [==============================] - 0s 390us/sample - loss: 0.0200 - val_loss: 0.0215
# Epoch 48/50
# 395/395 [==============================] - 0s 428us/sample - loss: 0.0198 - val_loss: 0.0213
# Epoch 49/50
# 395/395 [==============================] - 0s 411us/sample - loss: 0.0196 - val_loss: 0.0212
# Epoch 50/50
# 395/395 [==============================] - 0s 428us/sample - loss: 0.0196 - val_loss: 0.0208

# %%
# plot loss 
plt.figure(figsize=(15,8))
plt.plot(hist.history['loss'], label='loss')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.legend()

# %%
# Forecasting
forecast = []
last_actual = X_train[-1]  # first input sequence to the model
for t in range(X_test.shape[0]):
    predict = model.predict(last_actual.reshape(1,-1,1))
    predict = predict[0][0]  # get single scalar value
    
    # create next model input sequence
    last_actual = np.roll(last_actual,-1)
    last_actual[-1] = predict
    
    forecast.append(predict)

forecast = np.array(forecast)
print("Actual Y Test shape {} and Predicted Y Test shape {}".format(y_test.shape,forecast.shape))
# Out:
# Actual Y Test shape (95,) and Predicted Y Test shape (95,)

# %%
# plot actual vs Forecast
plt.figure(figsize=(15,5))
plt.plot(y_test,label='Actual')
plt.plot(forecast,label='Forecast')
plt.legend()
